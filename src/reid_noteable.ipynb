# %% [markdown]
# Prereqs
# 1. Create a new project and git clone the yolov5 "master" branch

# %%
# %ntbl pull datasets "BrainHack TIL-23 OD _ ReID Novice"
# Out:
# Dataset files are being pulled (this may take awhile)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #008000; text-decoration-color: #008000">Dataset files pulled from remote storage</span>
# </pre>

# %% [markdown]
# Might need to changed "../../datasets" to "../datasets" depending on your filepath

# %%
# !unzip "../../datasets/BrainHack TIL-23 OD _ ReID Novice/Train.zip" -d "/tmp/train_images"

# !unzip "../../datasets/BrainHack TIL-23 OD _ ReID Novice/train_labels.zip" -d "/tmp/train_labels"

# !unzip "../../datasets/BrainHack TIL-23 OD _ ReID Novice/Validation.zip" -d "/tmp/val_images"

# !unzip "../../datasets/BrainHack TIL-23 OD _ ReID Novice/val_labels.zip" -d "/tmp/val_labels"
# Out:
# Archive:  ../../datasets/BrainHack TIL-23 OD _ ReID Novice/Train.zip
#  extracting: /tmp/train_images/image_4655.png
#  extracting: /tmp/train_images/image_4676.png
#  extracting: /tmp/train_images/image_4654.png
#  extracting: /tmp/train_images/image_4667.png
#  extracting: /tmp/train_images/image_4660.png
#  extracting: /tmp/train_images/image_4680.png
#  extracting: /tmp/train_images/image_4673.png
#  extracting: /tmp/train_images/image_4674.png
#  extracting: /tmp/train_images/image_4670.png
#  extracting: /tmp/train_images/image_4661.png
#  extracting: /tmp/train_images/image_4671.png
#  extracting: /tmp/train_images/image_4664.png
#  extracting: /tmp/train_images/image_4685.png
#  extracting: /tmp/train_images/image_4666.png
#  extracting: /tmp/train_images/image_4659.png
#  extracting: /tmp/train_images/image_4663.png
#  extracting: /tmp/train_images/image_4656.png
#  extracting: /tmp/train_images/image_4675.png
#  extracting: /tmp/train_images/image_4684.png
#  extracting: /tmp/train_images/image_4682.png
#  extracting: /tmp/train_images/image_4681.png
#  extracting: /tmp/train_images/image_4679.png
#  extracting: /tmp/train_images/image_4713.png
#  extracting: /tmp/train_images/image_4693.png
#  extracting: /tmp/train_images/image_4695.png
#  extracting: /tmp/train_images/image_4690.png
#  extracting: /tmp/train_images/image_4689.png
#  extracting: /tmp/train_images/image_4697.png
#  extracting: /tmp/train_images/image_4698.png
#  extracting: /tmp/train_images/image_4711.png
#  extracting: /tmp/train_images/image_4706.png
#  extracting: /tmp/train_images/image_4709.png
#  extracting: /tmp/train_images/image_4702.png
#  extracting: /tmp/train_images/image_4696.png
#  extracting: /tmp/train_images/image_4707.png
#  extracting: /tmp/train_images/image_4701.png
#  extracting: /tmp/train_images/image_4708.png
#  extracting: /tmp/train_images/image_4712.png
#  extracting: /tmp/train_images/image_4705.png
#  extracting: /tmp/train_images/image_4714.png
#  extracting: /tmp/train_images/image_4691.png
#  extracting: /tmp/train_images/image_4710.png
#  extracting: /tmp/train_images/image_4699.png
#  extracting: /tmp/train_images/image_4700.png
#  extracting: /tmp/train_images/image_4688.png
#  extracting: /tmp/train_images/image_4704.png
#  extracting: /tmp/train_images/image_4703.png
#  extracting: /tmp/train_images/image_4715.png
#  extracting: /tmp/train_images/image_4687.png
#  extracting: /tmp/train_images/image_4694.png
#  extracting: /tmp/train_images/image_4686.png
#  extracting: /tmp/train_images/image_4692.png
#  extracting: /tmp/train_images/image_4738.png
#  extracting: /tmp/train_images/image_4722.png
#  extracting: /tmp/train_images/image_4736.png
#  extracting: /tmp/train_images/image_4728.png
#  extracting: /tmp/train_images/image_4720.png
#  extracting: /tmp/train_images/image_4727.png
#  extracting: /tmp/train_images/image_4744.png
#  extracting: /tmp/train_images/image_4716.png
#  extracting: /tmp/train_images/image_4743.png
#  extracting: /tmp/train_images/image_4718.png
#  extracting: /tmp/train_images/image_4726.png
#  extracting: /tmp/train_images/image_4737.png
#  extracting: /tmp/train_images/image_4717.png
#  extracting: /tmp/train_images/image_4746.png
#  extracting: /tmp/train_images/image_4723.png
#  extracting: /tmp/train_images/image_4721.png
#  extracting: /tmp/train_images/image_4719.png
#  extracting: /tmp/train_images/image_4741.png
#  extracting: /tmp/train_images/image_4734.png
#  extracting: /tmp/train_images/image_4725.png
#  extracting: /tmp/train_images/image_4731.png
#  extracting: /tmp/train_images/image_4735.png
#  extracting: /tmp/train_images/image_4739.png
#  extracting: /tmp/train_images/image_4730.png
#  extracting: /tmp/train_images/image_4745.png
#  extracting: /tmp/train_images/image_4733.png
#  extracting: /tmp/train_images/image_4724.png
#  extracting: /tmp/train_images/image_4740.png
#  extracting: /tmp/train_images/image_4742.png
#  extracting: /tmp/train_images/image_4729.png
#  extracting: /tmp/train_images/image_4732.png
#  extracting: /tmp/train_images/image_4753.png
#  extracting: /tmp/train_images/image_4757.png
#  extracting: /tmp/train_images/image_4758.png
#  extracting: /tmp/train_images/image_4755.png
#  extracting: /tmp/train_images/image_4775.png
#  extracting: /tmp/train_images/image_4777.png
#  extracting: /tmp/train_images/image_4772.png
#  extracting: /tmp/train_images/image_4769.png
#  extracting: /tmp/train_images/image_4761.png
#  extracting: /tmp/train_images/image_4750.png
#  extracting: /tmp/train_images/image_4764.png
#  extracting: /tmp/train_images/image_4763.png
#  extracting: /tmp/train_images/image_4768.png
#  extracting: /tmp/train_images/image_4762.png
#  extracting: /tmp/train_images/image_4770.png
#  extracting: /tmp/train_images/image_4771.png
#  extracting: /tmp/train_images/image_4765.png
#  extracting: /tmp/train_images/image_4751.png
#  extracting: /tmp/train_images/image_4754.png
#  extracting: /tmp/train_images/image_4760.png
#  extracting: /tmp/train_images/image_4767.png
#  extracting: /tmp/train_images/image_4752.png
#  extracting: /tmp/train_images/image_4756.png
#  extracting: /tmp/train_images/image_4773.png
#  extracting: /tmp/train_images/image_4776.png
#  extracting: /tmp/train_images/image_4747.png
#  extracting: /tmp/train_images/image_4749.png
#  extracting: /tmp/train_images/image_4748.png
#  extracting: /tmp/train_images/image_4759.png
#  extracting: /tmp/train_images/image_4774.png
#  extracting: /tmp/train_images/image_4766.png
#  extracting: /tmp/train_images/image_4804.png
#  extracting: /tmp/train_images/image_4784.png
#  extracting: /tmp/train_images/image_4794.png
#  extracting: /tmp/train_images/image_4796.png
#  extracting: /tmp/train_images/image_4802.png
#  extracting: /tmp/train_images/image_4780.png
#  extracting: /tmp/train_images/image_4785.png
#  extracting: /tmp/train_images/image_4792.png
#  extracting: /tmp/train_images/image_4782.png
#  extracting: /tmp/train_images/image_4778.png
#  extracting: /tmp/train_images/image_4808.png
#  extracting: /tmp/train_images/image_4781.png
#  extracting: /tmp/train_images/image_4791.png
#  extracting: /tmp/train_images/image_4800.png
#  extracting: /tmp/train_images/image_4790.png
#  extracting: /tmp/train_images/image_4787.png
#  extracting: /tmp/train_images/image_4801.png
#  extracting: /tmp/train_images/image_4795.png
#  extracting: /tmp/train_images/image_4786.png
#  extracting: /tmp/train_images/image_4789.png
#  extracting: /tmp/train_images/image_4788.png
#  extracting: /tmp/train_images/image_4807.png
#  extracting: /tmp/train_images/image_4797.png
#  extracting: /tmp/train_images/image_4799.png
#  extracting: /tmp/train_images/image_4783.png
#  extracting: /tmp/train_images/image_4805.png
#  extracting: /tmp/train_images/image_4798.png
#  extracting: /tmp/train_images/image_4806.png
#  extracting: /tmp/train_images/image_4803.png
#  extracting: /tmp/train_images/image_4779.png
#  extracting: /tmp/train_images/image_4793.png
#  extracting: /tmp/train_images/image_4829.png
#  extracting: /tmp/train_images/image_4810.png
#  extracting: /tmp/train_images/image_4817.png
#  extracting: /tmp/train_images/image_4833.png
#  extracting: /tmp/train_images/image_4820.png
#  extracting: /tmp/train_images/image_4814.png
#  extracting: /tmp/train_images/image_4823.png
#  extracting: /tmp/train_images/image_4831.png
#  extracting: /tmp/train_images/image_4809.png
#  extracting: /tmp/train_images/image_4826.png
#  extracting: /tmp/train_images/image_4834.png
#  extracting: /tmp/train_images/image_4835.png
#  extracting: /tmp/train_images/image_4830.png
#  extracting: /tmp/train_images/image_4828.png
#  extracting: /tmp/train_images/image_4836.png
#  extracting: /tmp/train_images/image_4825.png
#  extracting: /tmp/train_images/image_4821.png
#  extracting: /tmp/train_images/image_4832.png
#  extracting: /tmp/train_images/image_4837.png
#  extracting: /tmp/train_images/image_4815.png
#  extracting: /tmp/train_images/image_4813.png
#  extracting: /tmp/train_images/image_4824.png
#  extracting: /tmp/train_images/image_4819.png
#  extracting: /tmp/train_images/image_4818.png
#  extracting: /tmp/train_images/image_4822.png
#  extracting: /tmp/train_images/image_4816.png
#  extracting: /tmp/train_images/image_4812.png
#  extracting: /tmp/train_images/image_4838.png
#  extracting: /tmp/train_images/image_4811.png
#  extracting: /tmp/train_images/image_4827.png
#  extracting: /tmp/train_images/image_4851.png
#  extracting: /tmp/train_images/image_4841.png
#  extracting: /tmp/train_images/image_4849.png
#  extracting: /tmp/train_images/image_4865.png
#  extracting: /tmp/train_images/image_4862.png
#  extracting: /tmp/train_images/image_4850.png
#  extracting: /tmp/train_images/image_4868.png
#  extracting: /tmp/train_images/image_4866.png
#  extracting: /tmp/train_images/image_4867.png
#  extracting: /tmp/train_images/image_4840.png
#  extracting: /tmp/train_images/image_4846.png
#  extracting: /tmp/train_images/image_4843.png
#  extracting: /tmp/train_images/image_4848.png
#  extracting: /tmp/train_images/image_4845.png
#  extracting: /tmp/train_images/image_4863.png
#  extracting: /tmp/train_images/image_4854.png
#  extracting: /tmp/train_images/image_4869.png
#  extracting: /tmp/train_images/image_4858.png
#  extracting: /tmp/train_images/image_4852.png
#  extracting: /tmp/train_images/image_4847.png
#  extracting: /tmp/train_images/image_4864.png
#  extracting: /tmp/train_images/image_4861.png
#  extracting: /tmp/train_images/image_4855.png
#  extracting: /tmp/train_images/image_4853.png
#  extracting: /tmp/train_images/image_4842.png
#  extracting: /tmp/train_images/image_4857.png
#  extracting: /tmp/train_images/image_4870.png
#  extracting: /tmp/train_images/image_4871.png
#  extracting: /tmp/train_images/image_4844.png
#  extracting: /tmp/train_images/image_4859.png
#  extracting: /tmp/train_images/image_4856.png
#  extracting: /tmp/train_images/image_4839.png
#  extracting: /tmp/train_images/image_4860.png
#  extracting: /tmp/train_images/image_4897.png
#  extracting: /tmp/train_images/image_4885.png
#  extracting: /tmp/train_images/image_4874.png
#  extracting: /tmp/train_images/image_4876.png
#  extracting: /tmp/train_images/image_4883.png
#  extracting: /tmp/train_images/image_4896.png
#  extracting: /tmp/train_images/image_4903.png
#  extracting: /tmp/train_images/image_4889.png
#  extracting: /tmp/train_images/image_4900.png
#  extracting: /tmp/train_images/image_4887.png
#  extracting: /tmp/train_images/image_4901.png
#  extracting: /tmp/train_images/image_4888.png
#  extracting: /tmp/train_images/image_4893.png
#  extracting: /tmp/train_images/image_4877.png
#  extracting: /tmp/train_images/image_4899.png
#  extracting: /tmp/train_images/image_4895.png
#  extracting: /tmp/train_images/image_4898.png
#  extracting: /tmp/train_images/image_4873.png
#  extracting: /tmp/train_images/image_4890.png
#  extracting: /tmp/train_images/image_4902.png
#  extracting: /tmp/train_images/image_4872.png
#  extracting: /tmp/train_images/image_4886.png
#  extracting: /tmp/train_images/image_4884.png
#  extracting: /tmp/train_images/image_4875.png
#  extracting: /tmp/train_images/image_4891.png
#  extracting: /tmp/train_images/image_4879.png
#  extracting: /tmp/train_images/image_4878.png
#  extracting: /tmp/train_images/image_4880.png
#  extracting: /tmp/train_images/image_4894.png
#  extracting: /tmp/train_images/image_4892.png
#  extracting: /tmp/train_images/image_4882.png
#  extracting: /tmp/train_images/image_4881.png
#  extracting: /tmp/train_images/image_4927.png
#  extracting: /tmp/train_images/image_4925.png
#  extracting: /tmp/train_images/image_4922.png
#  extracting: /tmp/train_images/image_4930.png
#  extracting: /tmp/train_images/image_4935.png
#  extracting: /tmp/train_images/image_4911.png
#  extracting: /tmp/train_images/image_4924.png
#  extracting: /tmp/train_images/image_4915.png
#  extracting: /tmp/train_images/image_4916.png
#  extracting: /tmp/train_images/image_4926.png
#  extracting: /tmp/train_images/image_4919.png
#  extracting: /tmp/train_images/image_4918.png
#  extracting: /tmp/train_images/image_4904.png
#  extracting: /tmp/train_images/image_4931.png
#  extracting: /tmp/train_images/image_4907.png
#  extracting: /tmp/train_images/image_4923.png
#  extracting: /tmp/train_images/image_4929.png
#  extracting: /tmp/train_images/image_4913.png
#  extracting: /tmp/train_images/image_4921.png
#  extracting: /tmp/train_images/image_4908.png
#  extracting: /tmp/train_images/image_4905.png
#  extracting: /tmp/train_images/image_4934.png
#  extracting: /tmp/train_images/image_4933.png
#  extracting: /tmp/train_images/image_4914.png
#  extracting: /tmp/train_images/image_4910.png
#  extracting: /tmp/train_images/image_4906.png
#  extracting: /tmp/train_images/image_4928.png
#  extracting: /tmp/train_images/image_4920.png
#  extracting: /tmp/train_images/image_4909.png
#  extracting: /tmp/train_images/image_4932.png
#  extracting: /tmp/train_images/image_4912.png
#  extracting: /tmp/train_images/image_4917.png
#  extracting: /tmp/train_images/image_4940.png
#  extracting: /tmp/train_images/image_4943.png
#  extracting: /tmp/train_images/image_4947.png
#  extracting: /tmp/train_images/image_4963.png
#  extracting: /tmp/train_images/image_4945.png
#  extracting: /tmp/train_images/image_4959.png
#  extracting: /tmp/train_images/image_4951.png
#  extracting: /tmp/train_images/image_4962.png
#  extracting: /tmp/train_images/image_4950.png
#  extracting: /tmp/train_images/image_4944.png
#  extracting: /tmp/train_images/image_4953.png
#  extracting: /tmp/train_images/image_4961.png
#  extracting: /tmp/train_images/image_4942.png
#  extracting: /tmp/train_images/image_4941.png
#  extracting: /tmp/train_images/image_4949.png
#  extracting: /tmp/train_images/image_4960.png
#  extracting: /tmp/train_images/image_4965.png
#  extracting: /tmp/train_images/image_4952.png
#  extracting: /tmp/train_images/image_4938.png
#  extracting: /tmp/train_images/image_4936.png
#  extracting: /tmp/train_images/image_4956.png
#  extracting: /tmp/train_images/image_4957.png
#  extracting: /tmp/train_images/image_4964.png
#  extracting: /tmp/train_images/image_4946.png
#  extracting: /tmp/train_images/image_4937.png
#  extracting: /tmp/train_images/image_4939.png
#  extracting: /tmp/train_images/image_4948.png
#  extracting: /tmp/train_images/image_4954.png
#  extracting: /tmp/train_images/image_4955.png
#  extracting: /tmp/train_images/image_4958.png
#  extracting: /tmp/train_images/image_4985.png
#  extracting: /tmp/train_images/image_4982.png
#  extracting: /tmp/train_images/image_4993.png
#  extracting: /tmp/train_images/image_4969.png
#  extracting: /tmp/train_images/image_4992.png
#  extracting: /tmp/train_images/image_4977.png
#  extracting: /tmp/train_images/image_4989.png
#  extracting: /tmp/train_images/image_4981.png
#  extracting: /tmp/train_images/image_4987.png
#  extracting: /tmp/train_images/image_4995.png
#  extracting: /tmp/train_images/image_4973.png
#  extracting: /tmp/train_images/image_4979.png
#  extracting: /tmp/train_images/image_4967.png
#  extracting: /tmp/train_images/image_4972.png
#  extracting: /tmp/train_images/image_4986.png
#  extracting: /tmp/train_images/image_4966.png
#  extracting: /tmp/train_images/image_4971.png
#  extracting: /tmp/train_images/image_4968.png
#  extracting: /tmp/train_images/image_4970.png
#  extracting: /tmp/train_images/image_4980.png
#  extracting: /tmp/train_images/image_4976.png
#  extracting: /tmp/train_images/image_4994.png
#  extracting: /tmp/train_images/image_4991.png
#  extracting: /tmp/train_images/image_4975.png
#  extracting: /tmp/train_images/image_4988.png
#  extracting: /tmp/train_images/image_4996.png
#  extracting: /tmp/train_images/image_4978.png
#  extracting: /tmp/train_images/image_4983.png
#  extracting: /tmp/train_images/image_4974.png
#  extracting: /tmp/train_images/image_4990.png
#  extracting: /tmp/train_images/image_4984.png
#  extracting: /tmp/train_images/image_5013.png
#  extracting: /tmp/train_images/image_5018.png
#  extracting: /tmp/train_images/image_5014.png
#  extracting: /tmp/train_images/image_5017.png
#  extracting: /tmp/train_images/image_5007.png
#  extracting: /tmp/train_images/image_5002.png
#  extracting: /tmp/train_images/image_5025.png
#  extracting: /tmp/train_images/image_5000.png
#  extracting: /tmp/train_images/image_5026.png
#  extracting: /tmp/train_images/image_5024.png
#  extracting: /tmp/train_images/image_5001.png
#  extracting: /tmp/train_images/image_5010.png
#  extracting: /tmp/train_images/image_5005.png
#  extracting: /tmp/train_images/image_5006.png
#  extracting: /tmp/train_images/image_5004.png
#  extracting: /tmp/train_images/image_5012.png
#  extracting: /tmp/train_images/image_5023.png
#  extracting: /tmp/train_images/image_5016.png
#  extracting: /tmp/train_images/image_4998.png
#  extracting: /tmp/train_images/image_5015.png
#  extracting: /tmp/train_images/image_4997.png
#  extracting: /tmp/train_images/image_5022.png
#  extracting: /tmp/train_images/image_5003.png
#  extracting: /tmp/train_images/image_5021.png
#  extracting: /tmp/train_images/image_5020.png
#  extracting: /tmp/train_images/image_4999.png
#  extracting: /tmp/train_images/image_5019.png
#  extracting: /tmp/train_images/image_5009.png
#  extracting: /tmp/train_images/image_5011.png
#  extracting: /tmp/train_images/image_5027.png
#  extracting: /tmp/train_images/image_5008.png
#  extracting: /tmp/train_images/image_5039.png
#  extracting: /tmp/train_images/image_5032.png
#  extracting: /tmp/train_images/image_5029.png
#  extracting: /tmp/train_images/image_5055.png
#  extracting: /tmp/train_images/image_5038.png
#  extracting: /tmp/train_images/image_5044.png
#  extracting: /tmp/train_images/image_5054.png
#  extracting: /tmp/train_images/image_5034.png
#  extracting: /tmp/train_images/image_5043.png
#  extracting: /tmp/train_images/image_5050.png
#  extracting: /tmp/train_images/image_5041.png
#  extracting: /tmp/train_images/image_5033.png
#  extracting: /tmp/train_images/image_5056.png
#  extracting: /tmp/train_images/image_5048.png
#  extracting: /tmp/train_images/image_5049.png
#  extracting: /tmp/train_images/image_5058.png
#  extracting: /tmp/train_images/image_5047.png
#  extracting: /tmp/train_images/image_5045.png
#  extracting: /tmp/train_images/image_5046.png
#  extracting: /tmp/train_images/image_5028.png
#  extracting: /tmp/train_images/image_5053.png
#  extracting: /tmp/train_images/image_5052.png
#  extracting: /tmp/train_images/image_5040.png
#  extracting: /tmp/train_images/image_5030.png
#  extracting: /tmp/train_images/image_5051.png
#  extracting: /tmp/train_images/image_5057.png
#  extracting: /tmp/train_images/image_5035.png
#  extracting: /tmp/train_images/image_5042.png
#  extracting: /tmp/train_images/image_5031.png
#  extracting: /tmp/train_images/image_5036.png
#  extracting: /tmp/train_images/image_5037.png
#  extracting: /tmp/train_images/image_5059.png
#  extracting: /tmp/train_images/image_5061.png
#  extracting: /tmp/train_images/image_5078.png
#  extracting: /tmp/train_images/image_5076.png
#  extracting: /tmp/train_images/image_5060.png
#  extracting: /tmp/train_images/image_5084.png
#  extracting: /tmp/train_images/image_5064.png
#  extracting: /tmp/train_images/image_5072.png
#  extracting: /tmp/train_images/image_5070.png
#  extracting: /tmp/train_images/image_5088.png
#  extracting: /tmp/train_images/image_5077.png
#  extracting: /tmp/train_images/image_5083.png
#  extracting: /tmp/train_images/image_5066.png
#  extracting: /tmp/train_images/image_5080.png
#  extracting: /tmp/train_images/image_5065.png
#  extracting: /tmp/train_images/image_5087.png
#  extracting: /tmp/train_images/image_5073.png
#  extracting: /tmp/train_images/image_5067.png
#  extracting: /tmp/train_images/image_5063.png
#  extracting: /tmp/train_images/image_5089.png
#  extracting: /tmp/train_images/image_5069.png
#  extracting: /tmp/train_images/image_5075.png
#  extracting: /tmp/train_images/image_5071.png
#  extracting: /tmp/train_images/image_5079.png
#  extracting: /tmp/train_images/image_5081.png
#  extracting: /tmp/train_images/image_5085.png
#  extracting: /tmp/train_images/image_5068.png
#  extracting: /tmp/train_images/image_5082.png
#  extracting: /tmp/train_images/image_5086.png
#  extracting: /tmp/train_images/image_5062.png
#  extracting: /tmp/train_images/image_5074.png
#  extracting: /tmp/train_images/image_5100.png
#  extracting: /tmp/train_images/image_5121.png
#  extracting: /tmp/train_images/image_5110.png
#  extracting: /tmp/train_images/image_5093.png
#  extracting: /tmp/train_images/image_5090.png
#  extracting: /tmp/train_images/image_5101.png
#  extracting: /tmp/train_images/image_5091.png
#  extracting: /tmp/train_images/image_5117.png
#  extracting: /tmp/train_images/image_5097.png
#  extracting: /tmp/train_images/image_5111.png
#  extracting: /tmp/train_images/image_5106.png
#  extracting: /tmp/train_images/image_5096.png
#  extracting: /tmp/train_images/image_5092.png
#  extracting: /tmp/train_images/image_5094.png
#  extracting: /tmp/train_images/image_5104.png
#  extracting: /tmp/train_images/image_5098.png
#  extracting: /tmp/train_images/image_5103.png
#  extracting: /tmp/train_images/image_5095.png
#  extracting: /tmp/train_images/image_5109.png
#  extracting: /tmp/train_images/image_5118.png
#  extracting: /tmp/train_images/image_5113.png
#  extracting: /tmp/train_images/image_5119.png
#  extracting: /tmp/train_images/image_5108.png
#  extracting: /tmp/train_images/image_5114.png
#  extracting: /tmp/train_images/image_5105.png
#  extracting: /tmp/train_images/image_5112.png
#  extracting: /tmp/train_images/image_5115.png
#  extracting: /tmp/train_images/image_5102.png
#  extracting: /tmp/train_images/image_5116.png
#  extracting: /tmp/train_images/image_5120.png
#  extracting: /tmp/train_images/image_5099.png
#  extracting: /tmp/train_images/image_5107.png
#  extracting: /tmp/train_images/image_5127.png
#  extracting: /tmp/train_images/image_5130.png
#  extracting: /tmp/train_images/image_5135.png
#  extracting: /tmp/train_images/image_5129.png
#  extracting: /tmp/train_images/image_5147.png
#  extracting: /tmp/train_images/image_5153.png
#  extracting: /tmp/train_images/image_5140.png
#  extracting: /tmp/train_images/image_5137.png
#  extracting: /tmp/train_images/image_5136.png
#  extracting: /tmp/train_images/image_5142.png
#  extracting: /tmp/train_images/image_5139.png
#  extracting: /tmp/train_images/image_5150.png
#  extracting: /tmp/train_images/image_5148.png
#  extracting: /tmp/train_images/image_5146.png
#  extracting: /tmp/train_images/image_5123.png
#  extracting: /tmp/train_images/image_5128.png
#  extracting: /tmp/train_images/image_5133.png
#  extracting: /tmp/train_images/image_5131.png
#  extracting: /tmp/train_images/image_5126.png
#  extracting: /tmp/train_images/image_5124.png
#  extracting: /tmp/train_images/image_5134.png
#  extracting: /tmp/train_images/image_5138.png
#  extracting: /tmp/train_images/image_5152.png
#  extracting: /tmp/train_images/image_5151.png
#  extracting: /tmp/train_images/image_5125.png
#  extracting: /tmp/train_images/image_5143.png
#  extracting: /tmp/train_images/image_5145.png
#  extracting: /tmp/train_images/image_5149.png
#  extracting: /tmp/train_images/image_5132.png
#  extracting: /tmp/train_images/image_5141.png
#  extracting: /tmp/train_images/image_5144.png
#  extracting: /tmp/train_images/image_5122.png
#  extracting: /tmp/train_images/image_5178.png
#  extracting: /tmp/train_images/image_5168.png
#  extracting: /tmp/train_images/image_5169.png
#  extracting: /tmp/train_images/image_5162.png
#  extracting: /tmp/train_images/image_5175.png
#  extracting: /tmp/train_images/image_5166.png
#  extracting: /tmp/train_images/image_5158.png
#  extracting: /tmp/train_images/image_5156.png
#  extracting: /tmp/train_images/image_5179.png
#  extracting: /tmp/train_images/image_5154.png
#  extracting: /tmp/train_images/image_5176.png
#  extracting: /tmp/train_images/image_5159.png
#  extracting: /tmp/train_images/image_5174.png
#  extracting: /tmp/train_images/image_5183.png
#  extracting: /tmp/train_images/image_5171.png
#  extracting: /tmp/train_images/image_5155.png
#  extracting: /tmp/train_images/image_5165.png
#  extracting: /tmp/train_images/image_5173.png
#  extracting: /tmp/train_images/image_5167.png
#  extracting: /tmp/train_images/image_5157.png
#  extracting: /tmp/train_images/image_5177.png
#  extracting: /tmp/train_images/image_5180.png
#  extracting: /tmp/train_images/image_5181.png
#  extracting: /tmp/train_images/image_5170.png
#  extracting: /tmp/train_images/image_5163.png
#  extracting: /tmp/train_images/image_5164.png
#  extracting: /tmp/train_images/image_5161.png
#  extracting: /tmp/train_images/image_5182.png
#  extracting: /tmp/train_images/image_5172.png
#  extracting: /tmp/train_images/image_5160.png
#  extracting: /tmp/train_images/image_5186.png
#  extracting: /tmp/train_images/image_5188.png
#  extracting: /tmp/train_images/image_5187.png
#  extracting: /tmp/train_images/image_5211.png
#  extracting: /tmp/train_images/image_5190.png
#  extracting: /tmp/train_images/image_5200.png
#  extracting: /tmp/train_images/image_5205.png
#  extracting: /tmp/train_images/image_5191.png
#  extracting: /tmp/train_images/image_5213.png
#  extracting: /tmp/train_images/image_5208.png
#  extracting: /tmp/train_images/image_5201.png
#  extracting: /tmp/train_images/image_5197.png
#  extracting: /tmp/train_images/image_5192.png
#  extracting: /tmp/train_images/image_5210.png
#  extracting: /tmp/train_images/image_5207.png
#  extracting: /tmp/train_images/image_5194.png
#  extracting: /tmp/train_images/image_5195.png
#  extracting: /tmp/train_images/image_5202.png
#  extracting: /tmp/train_images/image_5199.png
#  extracting: /tmp/train_images/image_5185.png
#  extracting: /tmp/train_images/image_5214.png
#  extracting: /tmp/train_images/image_5193.png
#  extracting: /tmp/train_images/image_5184.png
#  extracting: /tmp/train_images/image_5203.png
#  extracting: /tmp/train_images/image_5209.png
#  extracting: /tmp/train_images/image_5189.png
#  extracting: /tmp/train_images/image_5212.png
#  extracting: /tmp/train_images/image_5204.png
#  extracting: /tmp/train_images/image_5206.png
#  extracting: /tmp/train_images/image_5196.png
#  extracting: /tmp/train_images/image_5198.png
#  extracting: /tmp/train_images/image_5224.png
#  extracting: /tmp/train_images/image_5234.png
#  extracting: /tmp/train_images/image_5243.png
#  extracting: /tmp/train_images/image_5223.png
#  extracting: /tmp/train_images/image_5217.png
#  extracting: /tmp/train_images/image_5238.png
#  extracting: /tmp/train_images/image_5230.png
#  extracting: /tmp/train_images/image_5225.png
#  extracting: /tmp/train_images/image_5216.png
#  extracting: /tmp/train_images/image_5241.png
#  extracting: /tmp/train_images/image_5226.png
#  extracting: /tmp/train_images/image_5228.png
#  extracting: /tmp/train_images/image_5227.png
#  extracting: /tmp/train_images/image_5221.png
#  extracting: /tmp/train_images/image_5236.png
#  extracting: /tmp/train_images/image_5239.png
#  extracting: /tmp/train_images/image_5231.png
#  extracting: /tmp/train_images/image_5222.png
#  extracting: /tmp/train_images/image_5215.png
#  extracting: /tmp/train_images/image_5219.png
#  extracting: /tmp/train_images/image_5237.png
#  extracting: /tmp/train_images/image_5240.png
#  extracting: /tmp/train_images/image_5242.png
#  extracting: /tmp/train_images/image_5232.png
#  extracting: /tmp/train_images/image_5244.png
#  extracting: /tmp/train_images/image_5218.png
#  extracting: /tmp/train_images/image_5235.png
#  extracting: /tmp/train_images/image_5233.png
#  extracting: /tmp/train_images/image_5220.png
#  extracting: /tmp/train_images/image_5229.png
#  extracting: /tmp/train_images/image_5256.png
#  extracting: /tmp/train_images/image_5269.png
#  extracting: /tmp/train_images/image_5264.png
#  extracting: /tmp/train_images/image_5255.png
#  extracting: /tmp/train_images/image_5247.png
#  extracting: /tmp/train_images/image_5253.png
#  extracting: /tmp/train_images/image_5252.png
#  extracting: /tmp/train_images/image_5254.png
#  extracting: /tmp/train_images/image_5266.png
#  extracting: /tmp/train_images/image_5268.png
#  extracting: /tmp/train_images/image_5263.png
#  extracting: /tmp/train_images/image_5259.png
#  extracting: /tmp/train_images/image_5261.png
#  extracting: /tmp/train_images/image_5258.png
#  extracting: /tmp/train_images/image_5251.png
#  extracting: /tmp/train_images/image_5270.png
#  extracting: /tmp/train_images/image_5250.png
#  extracting: /tmp/train_images/image_5265.png
#  extracting: /tmp/train_images/image_5245.png
#  extracting: /tmp/train_images/image_5257.png
#  extracting: /tmp/train_images/image_5246.png
#  extracting: /tmp/train_images/image_5267.png
#  extracting: /tmp/train_images/image_5271.png
#  extracting: /tmp/train_images/image_5262.png
#  extracting: /tmp/train_images/image_5248.png
#  extracting: /tmp/train_images/image_5260.png
#  extracting: /tmp/train_images/image_5249.png
#  extracting: /tmp/train_images/image_5278.png
#  extracting: /tmp/train_images/image_5283.png
#  extracting: /tmp/train_images/image_5298.png
#  extracting: /tmp/train_images/image_5274.png
#  extracting: /tmp/train_images/image_5296.png
#  extracting: /tmp/train_images/image_5301.png
#  extracting: /tmp/train_images/image_5295.png
#  extracting: /tmp/train_images/image_5299.png
#  extracting: /tmp/train_images/image_5281.png
#  extracting: /tmp/train_images/image_5285.png
#  extracting: /tmp/train_images/image_5279.png
#  extracting: /tmp/train_images/image_5275.png
#  extracting: /tmp/train_images/image_5282.png
#  extracting: /tmp/train_images/image_5290.png
#  extracting: /tmp/train_images/image_5291.png
#  extracting: /tmp/train_images/image_5300.png
#  extracting: /tmp/train_images/image_5293.png
#  extracting: /tmp/train_images/image_5276.png
#  extracting: /tmp/train_images/image_5277.png
#  extracting: /tmp/train_images/image_5287.png
#  extracting: /tmp/train_images/image_5289.png
#  extracting: /tmp/train_images/image_5280.png
#  extracting: /tmp/train_images/image_5297.png
#  extracting: /tmp/train_images/image_5272.png
#  extracting: /tmp/train_images/image_5273.png
#  extracting: /tmp/train_images/image_5288.png
#  extracting: /tmp/train_images/image_5284.png
#  extracting: /tmp/train_images/image_5286.png
#  extracting: /tmp/train_images/image_5292.png
#  extracting: /tmp/train_images/image_5294.png
#  extracting: /tmp/train_images/image_5331.png
#  extracting: /tmp/train_images/image_5327.png
#  extracting: /tmp/train_images/image_5313.png
#  extracting: /tmp/train_images/image_5321.png
#  extracting: /tmp/train_images/image_5319.png
#  extracting: /tmp/train_images/image_5314.png
#  extracting: /tmp/train_images/image_5315.png
#  extracting: /tmp/train_images/image_5317.png
#  extracting: /tmp/train_images/image_5311.png
#  extracting: /tmp/train_images/image_5318.png
#  extracting: /tmp/train_images/image_5323.png
#  extracting: /tmp/train_images/image_5320.png
#  extracting: /tmp/train_images/image_5307.png
#  extracting: /tmp/train_images/image_5306.png
#  extracting: /tmp/train_images/image_5332.png
#  extracting: /tmp/train_images/image_5312.png
#  extracting: /tmp/train_images/image_5302.png
#  extracting: /tmp/train_images/image_5308.png
#  extracting: /tmp/train_images/image_5330.png
#  extracting: /tmp/train_images/image_5324.png
#  extracting: /tmp/train_images/image_5326.png
#  extracting: /tmp/train_images/image_5325.png
#  extracting: /tmp/train_images/image_5305.png
#  extracting: /tmp/train_images/image_5303.png
#  extracting: /tmp/train_images/image_5309.png
#  extracting: /tmp/train_images/image_5329.png
#  extracting: /tmp/train_images/image_5310.png
#  extracting: /tmp/train_images/image_5304.png
#  extracting: /tmp/train_images/image_5322.png
#  extracting: /tmp/train_images/image_5316.png
#  extracting: /tmp/train_images/image_5328.png
#  extracting: /tmp/train_images/image_5363.png
#  extracting: /tmp/train_images/image_5346.png
#  extracting: /tmp/train_images/image_5340.png
#  extracting: /tmp/train_images/image_5339.png
#  extracting: /tmp/train_images/image_5358.png
#  extracting: /tmp/train_images/image_5350.png
#  extracting: /tmp/train_images/image_5337.png
#  extracting: /tmp/train_images/image_5335.png
#  extracting: /tmp/train_images/image_5362.png
#  extracting: /tmp/train_images/image_5353.png
#  extracting: /tmp/train_images/image_5341.png
#  extracting: /tmp/train_images/image_5334.png
#  extracting: /tmp/train_images/image_5356.png
#  extracting: /tmp/train_images/image_5361.png
#  extracting: /tmp/train_images/image_5338.png
#  extracting: /tmp/train_images/image_5359.png
#  extracting: /tmp/train_images/image_5342.png
#  extracting: /tmp/train_images/image_5352.png
#  extracting: /tmp/train_images/image_5345.png
#  extracting: /tmp/train_images/image_5343.png
#  extracting: /tmp/train_images/image_5336.png
#  extracting: /tmp/train_images/image_5357.png
#  extracting: /tmp/train_images/image_5349.png
#  extracting: /tmp/train_images/image_5355.png
#  extracting: /tmp/train_images/image_5348.png
#  extracting: /tmp/train_images/image_5333.png
#  extracting: /tmp/train_images/image_5360.png
#  extracting: /tmp/train_images/image_5364.png
#  extracting: /tmp/train_images/image_5347.png
#  extracting: /tmp/train_images/image_5344.png
#  extracting: /tmp/train_images/image_5354.png
#  extracting: /tmp/train_images/image_5351.png
#  extracting: /tmp/train_images/image_5388.png
#  extracting: /tmp/train_images/image_5366.png
#  extracting: /tmp/train_images/image_5393.png
#  extracting: /tmp/train_images/image_5390.png
#  extracting: /tmp/train_images/image_5386.png
#  extracting: /tmp/train_images/image_5375.png
#  extracting: /tmp/train_images/image_5371.png
#  extracting: /tmp/train_images/image_5377.png
#  extracting: /tmp/train_images/image_5373.png
#  extracting: /tmp/train_images/image_5372.png
#  extracting: /tmp/train_images/image_5382.png
#  extracting: /tmp/train_images/image_5365.png
#  extracting: /tmp/train_images/image_5367.png
#  extracting: /tmp/train_images/image_5368.png
#  extracting: /tmp/train_images/image_5387.png
#  extracting: /tmp/train_images/image_5369.png
#  extracting: /tmp/train_images/image_5379.png
#  extracting: /tmp/train_images/image_5385.png
#  extracting: /tmp/train_images/image_5376.png
#  extracting: /tmp/train_images/image_5374.png
#  extracting: /tmp/train_images/image_5381.png
#  extracting: /tmp/train_images/image_5391.png
#  extracting: /tmp/train_images/image_5370.png
#  extracting: /tmp/train_images/image_5380.png
#  extracting: /tmp/train_images/image_5383.png
#  extracting: /tmp/train_images/image_5384.png
#  extracting: /tmp/train_images/image_5389.png
#  extracting: /tmp/train_images/image_5392.png
#  extracting: /tmp/train_images/image_5378.png
#  extracting: /tmp/train_images/image_5409.png
#  extracting: /tmp/train_images/image_5397.png
#  extracting: /tmp/train_images/image_5420.png
#  extracting: /tmp/train_images/image_5410.png
#  extracting: /tmp/train_images/image_5407.png
#  extracting: /tmp/train_images/image_5417.png
#  extracting: /tmp/train_images/image_5400.png
#  extracting: /tmp/train_images/image_5403.png
#  extracting: /tmp/train_images/image_5408.png
#  extracting: /tmp/train_images/image_5412.png
#  extracting: /tmp/train_images/image_5401.png
#  extracting: /tmp/train_images/image_5414.png
#  extracting: /tmp/train_images/image_5416.png
#  extracting: /tmp/train_images/image_5422.png
#  extracting: /tmp/train_images/image_5421.png
#  extracting: /tmp/train_images/image_5402.png
#  extracting: /tmp/train_images/image_5411.png
#  extracting: /tmp/train_images/image_5406.png
#  extracting: /tmp/train_images/image_5415.png
#  extracting: /tmp/train_images/image_5418.png
#  extracting: /tmp/train_images/image_5423.png
#  extracting: /tmp/train_images/image_5405.png
#  extracting: /tmp/train_images/image_5398.png
#  extracting: /tmp/train_images/image_5413.png
#  extracting: /tmp/train_images/image_5395.png
#  extracting: /tmp/train_images/image_5404.png
#  extracting: /tmp/train_images/image_5396.png
#  extracting: /tmp/train_images/image_5419.png
#  extracting: /tmp/train_images/image_5394.png
#  extracting: /tmp/train_images/image_5399.png
#  extracting: /tmp/train_images/image_5437.png
#  extracting: /tmp/train_images/image_5438.png
#  extracting: /tmp/train_images/image_5452.png
#  extracting: /tmp/train_images/image_5440.png
#  extracting: /tmp/train_images/image_5449.png
#  extracting: /tmp/train_images/image_5447.png
#  extracting: /tmp/train_images/image_5433.png
#  extracting: /tmp/train_images/image_5446.png
#  extracting: /tmp/train_images/image_5444.png
#  extracting: /tmp/train_images/image_5451.png
#  extracting: /tmp/train_images/image_5450.png
#  extracting: /tmp/train_images/image_5442.png
#  extracting: /tmp/train_images/image_5425.png
#  extracting: /tmp/train_images/image_5445.png
#  extracting: /tmp/train_images/image_5441.png
#  extracting: /tmp/train_images/image_5430.png
#  extracting: /tmp/train_images/image_5434.png
#  extracting: /tmp/train_images/image_5432.png
#  extracting: /tmp/train_images/image_5429.png
#  extracting: /tmp/train_images/image_5448.png
#  extracting: /tmp/train_images/image_5439.png
#  extracting: /tmp/train_images/image_5443.png
#  extracting: /tmp/train_images/image_5453.png
#  extracting: /tmp/train_images/image_5435.png
#  extracting: /tmp/train_images/image_5428.png
#  extracting: /tmp/train_images/image_5431.png
#  extracting: /tmp/train_images/image_5436.png
#  extracting: /tmp/train_images/image_5424.png
#  extracting: /tmp/train_images/image_5426.png
#  extracting: /tmp/train_images/image_5427.png
#  extracting: /tmp/train_images/image_5463.png
#  extracting: /tmp/train_images/image_5471.png
#  extracting: /tmp/train_images/image_5475.png
#  extracting: /tmp/train_images/image_5466.png
#  extracting: /tmp/train_images/image_5467.png
#  extracting: /tmp/train_images/image_5472.png
#  extracting: /tmp/train_images/image_5455.png
#  extracting: /tmp/train_images/image_5457.png
#  extracting: /tmp/train_images/image_5479.png
#  extracting: /tmp/train_images/image_5482.png
#  extracting: /tmp/train_images/image_5465.png
#  extracting: /tmp/train_images/image_5468.png
#  extracting: /tmp/train_images/image_5469.png
#  extracting: /tmp/train_images/image_5456.png
#  extracting: /tmp/train_images/image_5476.png
#  extracting: /tmp/train_images/image_5461.png
#  extracting: /tmp/train_images/image_5480.png
#  extracting: /tmp/train_images/image_5483.png
#  extracting: /tmp/train_images/image_5464.png
#  extracting: /tmp/train_images/image_5462.png
#  extracting: /tmp/train_images/image_5481.png
#  extracting: /tmp/train_images/image_5474.png
#  extracting: /tmp/train_images/image_5460.png
#  extracting: /tmp/train_images/image_5470.png
#  extracting: /tmp/train_images/image_5458.png
#  extracting: /tmp/train_images/image_5477.png
#  extracting: /tmp/train_images/image_5478.png
#  extracting: /tmp/train_images/image_5454.png
#  extracting: /tmp/train_images/image_5473.png
#  extracting: /tmp/train_images/image_5459.png
#  extracting: /tmp/train_images/image_5495.png
#  extracting: /tmp/train_images/image_5509.png
#  extracting: /tmp/train_images/image_5502.png
#  extracting: /tmp/train_images/image_5499.png
#  extracting: /tmp/train_images/image_5484.png
#  extracting: /tmp/train_images/image_5486.png
#  extracting: /tmp/train_images/image_5490.png
#  extracting: /tmp/train_images/image_5489.png
#  extracting: /tmp/train_images/image_5492.png
#  extracting: /tmp/train_images/image_5485.png
#  extracting: /tmp/train_images/image_5498.png
#  extracting: /tmp/train_images/image_5507.png
#  extracting: /tmp/train_images/image_5497.png
#  extracting: /tmp/train_images/image_5491.png
#  extracting: /tmp/train_images/image_5506.png
#  extracting: /tmp/train_images/image_5510.png
#  extracting: /tmp/train_images/image_5494.png
#  extracting: /tmp/train_images/image_5501.png
#  extracting: /tmp/train_images/image_5505.png
#  extracting: /tmp/train_images/image_5496.png
#  extracting: /tmp/train_images/image_5488.png
#  extracting: /tmp/train_images/image_5503.png
#  extracting: /tmp/train_images/image_5493.png
#  extracting: /tmp/train_images/image_5508.png
#  extracting: /tmp/train_images/image_5487.png
#  extracting: /tmp/train_images/image_5504.png
#  extracting: /tmp/train_images/image_5500.png
#  extracting: /tmp/train_images/image_5511.png
#  extracting: /tmp/train_images/image_5528.png
#  extracting: /tmp/train_images/image_5518.png
#  extracting: /tmp/train_images/image_5525.png
#  extracting: /tmp/train_images/image_5515.png
#  extracting: /tmp/train_images/image_5536.png
#  extracting: /tmp/train_images/image_5512.png
#  extracting: /tmp/train_images/image_5533.png
#  extracting: /tmp/train_images/image_5535.png
#  extracting: /tmp/train_images/image_5516.png
#  extracting: /tmp/train_images/image_5520.png
#  extracting: /tmp/train_images/image_5530.png
#  extracting: /tmp/train_images/image_5534.png
#  extracting: /tmp/train_images/image_5532.png
#  extracting: /tmp/train_images/image_5527.png
#  extracting: /tmp/train_images/image_5539.png
#  extracting: /tmp/train_images/image_5531.png
#  extracting: /tmp/train_images/image_5519.png
#  extracting: /tmp/train_images/image_5537.png
#  extracting: /tmp/train_images/image_5514.png
#  extracting: /tmp/train_images/image_5523.png
#  extracting: /tmp/train_images/image_5524.png
#  extracting: /tmp/train_images/image_5517.png
#  extracting: /tmp/train_images/image_5526.png
#  extracting: /tmp/train_images/image_5540.png
#  extracting: /tmp/train_images/image_5522.png
#  extracting: /tmp/train_images/image_5513.png
#  extracting: /tmp/train_images/image_5538.png
#  extracting: /tmp/train_images/image_5529.png
#  extracting: /tmp/train_images/image_5521.png
#  extracting: /tmp/train_images/image_5555.png
#  extracting: /tmp/train_images/image_5543.png
#  extracting: /tmp/train_images/image_5550.png
#  extracting: /tmp/train_images/image_5545.png
#  extracting: /tmp/train_images/image_5552.png
#  extracting: /tmp/train_images/image_5566.png
#  extracting: /tmp/train_images/image_5562.png
#  extracting: /tmp/train_images/image_5557.png
#  extracting: /tmp/train_images/image_5563.png
#  extracting: /tmp/train_images/image_5558.png
#  extracting: /tmp/train_images/image_5556.png
#  extracting: /tmp/train_images/image_5560.png
#  extracting: /tmp/train_images/image_5544.png
#  extracting: /tmp/train_images/image_5565.png
#  extracting: /tmp/train_images/image_5551.png
#  extracting: /tmp/train_images/image_5553.png
#  extracting: /tmp/train_images/image_5546.png
#  extracting: /tmp/train_images/image_5564.png
#  extracting: /tmp/train_images/image_5547.png
#  extracting: /tmp/train_images/image_5559.png
#  extracting: /tmp/train_images/image_5548.png
#  extracting: /tmp/train_images/image_5554.png
#  extracting: /tmp/train_images/image_5568.png
#  extracting: /tmp/train_images/image_5561.png
#  extracting: /tmp/train_images/image_5567.png
#  extracting: /tmp/train_images/image_5549.png
#  extracting: /tmp/train_images/image_5542.png
#  extracting: /tmp/train_images/image_5541.png
#  extracting: /tmp/train_images/image_5590.png
#  extracting: /tmp/train_images/image_5580.png
#  extracting: /tmp/train_images/image_5574.png
#  extracting: /tmp/train_images/image_5595.png
#  extracting: /tmp/train_images/image_5586.png
#  extracting: /tmp/train_images/image_5573.png
#  extracting: /tmp/train_images/image_5585.png
#  extracting: /tmp/train_images/image_5576.png
#  extracting: /tmp/train_images/image_5583.png
#  extracting: /tmp/train_images/image_5575.png
#  extracting: /tmp/train_images/image_5597.png
#  extracting: /tmp/train_images/image_5593.png
#  extracting: /tmp/train_images/image_5584.png
#  extracting: /tmp/train_images/image_5596.png
#  extracting: /tmp/train_images/image_5571.png
#  extracting: /tmp/train_images/image_5577.png
#  extracting: /tmp/train_images/image_5589.png
#  extracting: /tmp/train_images/image_5582.png
#  extracting: /tmp/train_images/image_5588.png
#  extracting: /tmp/train_images/image_5592.png
#  extracting: /tmp/train_images/image_5591.png
#  extracting: /tmp/train_images/image_5581.png
#  extracting: /tmp/train_images/image_5572.png
#  extracting: /tmp/train_images/image_5598.png
#  extracting: /tmp/train_images/image_5587.png
#  extracting: /tmp/train_images/image_5569.png
#  extracting: /tmp/train_images/image_5579.png
#  extracting: /tmp/train_images/image_5570.png
#  extracting: /tmp/train_images/image_5594.png
#  extracting: /tmp/train_images/image_5578.png
#  extracting: /tmp/train_images/image_5615.png
#  extracting: /tmp/train_images/image_5628.png
#  extracting: /tmp/train_images/image_5623.png
#  extracting: /tmp/train_images/image_5616.png
#  extracting: /tmp/train_images/image_5612.png
#  extracting: /tmp/train_images/image_5624.png
#  extracting: /tmp/train_images/image_5608.png
#  extracting: /tmp/train_images/image_5600.png
#  extracting: /tmp/train_images/image_5606.png
#  extracting: /tmp/train_images/image_5605.png
#  extracting: /tmp/train_images/image_5626.png
#  extracting: /tmp/train_images/image_5610.png
#  extracting: /tmp/train_images/image_5601.png
#  extracting: /tmp/train_images/image_5602.png
#  extracting: /tmp/train_images/image_5617.png
#  extracting: /tmp/train_images/image_5622.png
#  extracting: /tmp/train_images/image_5627.png
#  extracting: /tmp/train_images/image_5604.png
#  extracting: /tmp/train_images/image_5607.png
#  extracting: /tmp/train_images/image_5620.png
#  extracting: /tmp/train_images/image_5625.png
#  extracting: /tmp/train_images/image_5618.png
#  extracting: /tmp/train_images/image_5609.png
#  extracting: /tmp/train_images/image_5599.png
#  extracting: /tmp/train_images/image_5621.png
#  extracting: /tmp/train_images/image_5614.png
#  extracting: /tmp/train_images/image_5611.png
#  extracting: /tmp/train_images/image_5619.png
#  extracting: /tmp/train_images/image_5613.png
#  extracting: /tmp/train_images/image_5603.png
#  extracting: /tmp/train_images/image_5629.png
#  extracting: /tmp/train_images/image_5635.png
#  extracting: /tmp/train_images/image_5638.png
#  extracting: /tmp/train_images/image_5641.png
#  extracting: /tmp/train_images/image_5649.png
#  extracting: /tmp/train_images/image_5631.png
#  extracting: /tmp/train_images/image_5655.png
#  extracting: /tmp/train_images/image_5648.png
#  extracting: /tmp/train_images/image_5659.png
#  extracting: /tmp/train_images/image_5636.png
#  extracting: /tmp/train_images/image_5652.png
#  extracting: /tmp/train_images/image_5633.png
#  extracting: /tmp/train_images/image_5656.png
#  extracting: /tmp/train_images/image_5639.png
#  extracting: /tmp/train_images/image_5642.png
#  extracting: /tmp/train_images/image_5646.png
#  extracting: /tmp/train_images/image_5654.png
#  extracting: /tmp/train_images/image_5657.png
#  extracting: /tmp/train_images/image_5651.png
#  extracting: /tmp/train_images/image_5630.png
#  extracting: /tmp/train_images/image_5650.png
#  extracting: /tmp/train_images/image_5637.png
#  extracting: /tmp/train_images/image_5647.png
#  extracting: /tmp/train_images/image_5634.png
#  extracting: /tmp/train_images/image_5645.png
#  extracting: /tmp/train_images/image_5632.png
#  extracting: /tmp/train_images/image_5643.png
#  extracting: /tmp/train_images/image_5653.png
#  extracting: /tmp/train_images/image_5640.png
#  extracting: /tmp/train_images/image_5644.png
#  extracting: /tmp/train_images/image_5658.png
#  extracting: /tmp/train_images/image_5663.png
#  extracting: /tmp/train_images/image_5660.png
#  extracting: /tmp/train_images/image_5661.png
#  extracting: /tmp/train_images/image_5662.png
#  extracting: /tmp/train_images/image_3677.png
#  extracting: /tmp/train_images/image_3654.png
#  extracting: /tmp/train_images/image_3665.png
#  extracting: /tmp/train_images/image_3651.png
#  extracting: /tmp/train_images/image_3659.png
#  extracting: /tmp/train_images/image_3655.png
#  extracting: /tmp/train_images/image_3671.png
#  extracting: /tmp/train_images/image_3652.png
#  extracting: /tmp/train_images/image_3658.png
#  extracting: /tmp/train_images/image_3672.png
#  extracting: /tmp/train_images/image_3664.png
#  extracting: /tmp/train_images/image_3657.png
#  extracting: /tmp/train_images/image_3670.png
#  extracting: /tmp/train_images/image_3653.png
# ...
#  extracting: /tmp/val_labels/image_0439.txt
#  extracting: /tmp/val_labels/image_0446.txt
#  extracting: /tmp/val_labels/image_0424.txt
#  extracting: /tmp/val_labels/image_0434.txt
#  extracting: /tmp/val_labels/image_0406.txt
#  extracting: /tmp/val_labels/image_0445.txt
#  extracting: /tmp/val_labels/image_0415.txt
#  extracting: /tmp/val_labels/image_0440.txt
#  extracting: /tmp/val_labels/image_0471.txt
#  extracting: /tmp/val_labels/image_0405.txt
#  extracting: /tmp/val_labels/image_0409.txt
#  extracting: /tmp/val_labels/image_0461.txt
#  extracting: /tmp/val_labels/image_0464.txt
#  extracting: /tmp/val_labels/image_0423.txt
#  extracting: /tmp/val_labels/image_0466.txt
#  extracting: /tmp/val_labels/image_0411.txt
#  extracting: /tmp/val_labels/image_0453.txt
#  extracting: /tmp/val_labels/image_0455.txt
#  extracting: /tmp/val_labels/image_0469.txt
#  extracting: /tmp/val_labels/image_0452.txt
#  extracting: /tmp/val_labels/image_0410.txt
#  extracting: /tmp/val_labels/image_0511.txt
#  extracting: /tmp/val_labels/image_0488.txt
#  extracting: /tmp/val_labels/image_0500.txt
#  extracting: /tmp/val_labels/image_0502.txt
#  extracting: /tmp/val_labels/image_0483.txt
#  extracting: /tmp/val_labels/image_0485.txt
#  extracting: /tmp/val_labels/image_0496.txt
#  extracting: /tmp/val_labels/image_0544.txt
#  extracting: /tmp/val_labels/image_0494.txt
#  extracting: /tmp/val_labels/image_0514.txt
#  extracting: /tmp/val_labels/image_0507.txt
#  extracting: /tmp/val_labels/image_0504.txt
#  extracting: /tmp/val_labels/image_0477.txt
#  extracting: /tmp/val_labels/image_0495.txt
#  extracting: /tmp/val_labels/image_0520.txt
#  extracting: /tmp/val_labels/image_0484.txt
#  extracting: /tmp/val_labels/image_0475.txt
#  extracting: /tmp/val_labels/image_0493.txt
#  extracting: /tmp/val_labels/image_0492.txt
#  extracting: /tmp/val_labels/image_0474.txt
#  extracting: /tmp/val_labels/image_0509.txt
#  extracting: /tmp/val_labels/image_0489.txt
#  extracting: /tmp/val_labels/image_0491.txt
#  extracting: /tmp/val_labels/image_0476.txt
#  extracting: /tmp/val_labels/image_0542.txt
#  extracting: /tmp/val_labels/image_0479.txt
#  extracting: /tmp/val_labels/image_0490.txt
#  extracting: /tmp/val_labels/image_0518.txt
#  extracting: /tmp/val_labels/image_0548.txt
#  extracting: /tmp/val_labels/image_0538.txt
#  extracting: /tmp/val_labels/image_0532.txt
#  extracting: /tmp/val_labels/image_0543.txt
#  extracting: /tmp/val_labels/image_0536.txt
#  extracting: /tmp/val_labels/image_0513.txt
#  extracting: /tmp/val_labels/image_0522.txt
#  extracting: /tmp/val_labels/image_0481.txt
#  extracting: /tmp/val_labels/image_0498.txt
#  extracting: /tmp/val_labels/image_0525.txt
#  extracting: /tmp/val_labels/image_0529.txt
#  extracting: /tmp/val_labels/image_0545.txt
#  extracting: /tmp/val_labels/image_0499.txt
#  extracting: /tmp/val_labels/image_0546.txt
#  extracting: /tmp/val_labels/image_0524.txt
#  extracting: /tmp/val_labels/image_0528.txt
#  extracting: /tmp/val_labels/image_0519.txt
#  extracting: /tmp/val_labels/image_0530.txt
#  extracting: /tmp/val_labels/image_0526.txt
#  extracting: /tmp/val_labels/image_0537.txt
#  extracting: /tmp/val_labels/image_0478.txt
#  extracting: /tmp/val_labels/image_0487.txt
#  extracting: /tmp/val_labels/image_0480.txt
#  extracting: /tmp/val_labels/image_0549.txt
#  extracting: /tmp/val_labels/image_0527.txt
#  extracting: /tmp/val_labels/image_0547.txt
#  extracting: /tmp/val_labels/image_0515.txt
#  extracting: /tmp/val_labels/image_0539.txt
#  extracting: /tmp/val_labels/image_0521.txt
#  extracting: /tmp/val_labels/image_0503.txt
#  extracting: /tmp/val_labels/image_0550.txt
#  extracting: /tmp/val_labels/image_0517.txt
#  extracting: /tmp/val_labels/image_0505.txt
#  extracting: /tmp/val_labels/image_0508.txt
#  extracting: /tmp/val_labels/image_0482.txt
#  extracting: /tmp/val_labels/image_0501.txt
#  extracting: /tmp/val_labels/image_0541.txt
#  extracting: /tmp/val_labels/image_0506.txt
#  extracting: /tmp/val_labels/image_0531.txt
#  extracting: /tmp/val_labels/image_0510.txt
#  extracting: /tmp/val_labels/image_0486.txt
#  extracting: /tmp/val_labels/image_0540.txt
#  extracting: /tmp/val_labels/image_0535.txt
#  extracting: /tmp/val_labels/image_0512.txt
#  extracting: /tmp/val_labels/image_0534.txt
#  extracting: /tmp/val_labels/image_0497.txt
#  extracting: /tmp/val_labels/image_0516.txt
#  extracting: /tmp/val_labels/image_0523.txt
#  extracting: /tmp/val_labels/image_0533.txt
#  extracting: /tmp/val_labels/image_0556.txt
#  extracting: /tmp/val_labels/image_0599.txt
#  extracting: /tmp/val_labels/image_0597.txt
#  extracting: /tmp/val_labels/image_0555.txt
#  extracting: /tmp/val_labels/image_0570.txt
#  extracting: /tmp/val_labels/image_0595.txt
#  extracting: /tmp/val_labels/image_0571.txt
#  extracting: /tmp/val_labels/image_0557.txt
#  extracting: /tmp/val_labels/image_0575.txt
#  extracting: /tmp/val_labels/image_0567.txt
#  extracting: /tmp/val_labels/image_0620.txt
#  extracting: /tmp/val_labels/image_0581.txt
#  extracting: /tmp/val_labels/image_0592.txt
#  extracting: /tmp/val_labels/image_0606.txt
#  extracting: /tmp/val_labels/image_0586.txt
#  extracting: /tmp/val_labels/image_0576.txt
#  extracting: /tmp/val_labels/image_0568.txt
#  extracting: /tmp/val_labels/image_0578.txt
#  extracting: /tmp/val_labels/image_0552.txt
#  extracting: /tmp/val_labels/image_0577.txt
#  extracting: /tmp/val_labels/image_0614.txt
#  extracting: /tmp/val_labels/image_0609.txt
#  extracting: /tmp/val_labels/image_0612.txt
#  extracting: /tmp/val_labels/image_0605.txt
#  extracting: /tmp/val_labels/image_0590.txt
#  extracting: /tmp/val_labels/image_0593.txt
#  extracting: /tmp/val_labels/image_0608.txt
#  extracting: /tmp/val_labels/image_0618.txt
#  extracting: /tmp/val_labels/image_0607.txt
#  extracting: /tmp/val_labels/image_0625.txt
#  extracting: /tmp/val_labels/image_0554.txt
#  extracting: /tmp/val_labels/image_0603.txt
#  extracting: /tmp/val_labels/image_0624.txt
#  extracting: /tmp/val_labels/image_0558.txt
#  extracting: /tmp/val_labels/image_0584.txt
#  extracting: /tmp/val_labels/image_0560.txt
#  extracting: /tmp/val_labels/image_0623.txt
#  extracting: /tmp/val_labels/image_0565.txt
#  extracting: /tmp/val_labels/image_0619.txt
#  extracting: /tmp/val_labels/image_0627.txt
#  extracting: /tmp/val_labels/image_0594.txt
#  extracting: /tmp/val_labels/image_0563.txt
#  extracting: /tmp/val_labels/image_0583.txt
#  extracting: /tmp/val_labels/image_0564.txt
#  extracting: /tmp/val_labels/image_0589.txt
#  extracting: /tmp/val_labels/image_0617.txt
#  extracting: /tmp/val_labels/image_0585.txt
#  extracting: /tmp/val_labels/image_0602.txt
#  extracting: /tmp/val_labels/image_0580.txt
#  extracting: /tmp/val_labels/image_0610.txt
#  extracting: /tmp/val_labels/image_0553.txt
#  extracting: /tmp/val_labels/image_0562.txt
#  extracting: /tmp/val_labels/image_0572.txt
#  extracting: /tmp/val_labels/image_0626.txt
#  extracting: /tmp/val_labels/image_0621.txt
#  extracting: /tmp/val_labels/image_0600.txt
#  extracting: /tmp/val_labels/image_0604.txt
#  extracting: /tmp/val_labels/image_0591.txt
#  extracting: /tmp/val_labels/image_0596.txt
#  extracting: /tmp/val_labels/image_0622.txt
#  extracting: /tmp/val_labels/image_0588.txt
#  extracting: /tmp/val_labels/image_0629.txt
#  extracting: /tmp/val_labels/image_0566.txt
#  extracting: /tmp/val_labels/image_0615.txt
#  extracting: /tmp/val_labels/image_0582.txt
#  extracting: /tmp/val_labels/image_0613.txt
#  extracting: /tmp/val_labels/image_0587.txt
#  extracting: /tmp/val_labels/image_0574.txt
#  extracting: /tmp/val_labels/image_0598.txt
#  extracting: /tmp/val_labels/image_0551.txt
#  extracting: /tmp/val_labels/image_0611.txt
#  extracting: /tmp/val_labels/image_0559.txt
#  extracting: /tmp/val_labels/image_0616.txt
#  extracting: /tmp/val_labels/image_0573.txt
#  extracting: /tmp/val_labels/image_0561.txt
#  extracting: /tmp/val_labels/image_0628.txt
#  extracting: /tmp/val_labels/image_0569.txt
#  extracting: /tmp/val_labels/image_0601.txt
#  extracting: /tmp/val_labels/image_0579.txt
#  extracting: /tmp/val_labels/image_0683.txt
#  extracting: /tmp/val_labels/image_0705.txt
#  extracting: /tmp/val_labels/image_0692.txt
#  extracting: /tmp/val_labels/image_0685.txt
#  extracting: /tmp/val_labels/image_0673.txt
#  extracting: /tmp/val_labels/image_0701.txt
#  extracting: /tmp/val_labels/image_0634.txt
#  extracting: /tmp/val_labels/image_0637.txt
#  extracting: /tmp/val_labels/image_0635.txt
#  extracting: /tmp/val_labels/image_0682.txt
#  extracting: /tmp/val_labels/image_0645.txt
#  extracting: /tmp/val_labels/image_0651.txt
#  extracting: /tmp/val_labels/image_0664.txt
#  extracting: /tmp/val_labels/image_0691.txt
#  extracting: /tmp/val_labels/image_0660.txt
#  extracting: /tmp/val_labels/image_0648.txt
#  extracting: /tmp/val_labels/image_0704.txt
#  extracting: /tmp/val_labels/image_0702.txt
#  extracting: /tmp/val_labels/image_0696.txt
#  extracting: /tmp/val_labels/image_0680.txt
#  extracting: /tmp/val_labels/image_0686.txt
#  extracting: /tmp/val_labels/image_0641.txt
#  extracting: /tmp/val_labels/image_0699.txt
#  extracting: /tmp/val_labels/image_0655.txt
#  extracting: /tmp/val_labels/image_0706.txt
#  extracting: /tmp/val_labels/image_0639.txt
#  extracting: /tmp/val_labels/image_0650.txt
#  extracting: /tmp/val_labels/image_0688.txt
#  extracting: /tmp/val_labels/image_0677.txt
#  extracting: /tmp/val_labels/image_0662.txt
#  extracting: /tmp/val_labels/image_0698.txt
#  extracting: /tmp/val_labels/image_0666.txt
#  extracting: /tmp/val_labels/image_0636.txt
#  extracting: /tmp/val_labels/image_0707.txt
#  extracting: /tmp/val_labels/image_0703.txt
#  extracting: /tmp/val_labels/image_0690.txt
#  extracting: /tmp/val_labels/image_0633.txt
#  extracting: /tmp/val_labels/image_0681.txt
#  extracting: /tmp/val_labels/image_0652.txt
#  extracting: /tmp/val_labels/image_0671.txt
#  extracting: /tmp/val_labels/image_0679.txt
#  extracting: /tmp/val_labels/image_0638.txt
#  extracting: /tmp/val_labels/image_0687.txt
#  extracting: /tmp/val_labels/image_0668.txt
#  extracting: /tmp/val_labels/image_0676.txt
#  extracting: /tmp/val_labels/image_0665.txt
#  extracting: /tmp/val_labels/image_0631.txt
#  extracting: /tmp/val_labels/image_0647.txt
#  extracting: /tmp/val_labels/image_0695.txt
#  extracting: /tmp/val_labels/image_0630.txt
#  extracting: /tmp/val_labels/image_0678.txt
#  extracting: /tmp/val_labels/image_0653.txt
#  extracting: /tmp/val_labels/image_0643.txt
#  extracting: /tmp/val_labels/image_0674.txt
#  extracting: /tmp/val_labels/image_0646.txt
#  extracting: /tmp/val_labels/image_0649.txt
#  extracting: /tmp/val_labels/image_0689.txt
#  extracting: /tmp/val_labels/image_0667.txt
#  extracting: /tmp/val_labels/image_0642.txt
#  extracting: /tmp/val_labels/image_0659.txt
#  extracting: /tmp/val_labels/image_0693.txt
#  extracting: /tmp/val_labels/image_0644.txt
#  extracting: /tmp/val_labels/image_0672.txt
#  extracting: /tmp/val_labels/image_0694.txt
#  extracting: /tmp/val_labels/image_0658.txt
#  extracting: /tmp/val_labels/image_0654.txt
#  extracting: /tmp/val_labels/image_0670.txt
#  extracting: /tmp/val_labels/image_0675.txt
#  extracting: /tmp/val_labels/image_0669.txt
#  extracting: /tmp/val_labels/image_0697.txt
#  extracting: /tmp/val_labels/image_0684.txt
#  extracting: /tmp/val_labels/image_0632.txt
#  extracting: /tmp/val_labels/image_0656.txt
#  extracting: /tmp/val_labels/image_0661.txt
#  extracting: /tmp/val_labels/image_0640.txt
#  extracting: /tmp/val_labels/image_0663.txt
#  extracting: /tmp/val_labels/image_0700.txt
#  extracting: /tmp/val_labels/image_0657.txt
#  extracting: /tmp/val_labels/image_0708.txt
#  extracting: /tmp/val_labels/image_0747.txt
#  extracting: /tmp/val_labels/image_0761.txt
#  extracting: /tmp/val_labels/image_0746.txt
#  extracting: /tmp/val_labels/image_0737.txt
#  extracting: /tmp/val_labels/image_0713.txt
#  extracting: /tmp/val_labels/image_0745.txt
#  extracting: /tmp/val_labels/image_0740.txt
#  extracting: /tmp/val_labels/image_0717.txt
#  extracting: /tmp/val_labels/image_0767.txt
#  extracting: /tmp/val_labels/image_0777.txt
#  extracting: /tmp/val_labels/image_0738.txt
#  extracting: /tmp/val_labels/image_0753.txt
#  extracting: /tmp/val_labels/image_0774.txt
#  extracting: /tmp/val_labels/image_0748.txt
#  extracting: /tmp/val_labels/image_0744.txt
#  extracting: /tmp/val_labels/image_0709.txt
#  extracting: /tmp/val_labels/image_0734.txt
#  extracting: /tmp/val_labels/image_0778.txt
#  extracting: /tmp/val_labels/image_0725.txt
#  extracting: /tmp/val_labels/image_0731.txt
#  extracting: /tmp/val_labels/image_0711.txt
#  extracting: /tmp/val_labels/image_0733.txt
#  extracting: /tmp/val_labels/image_0764.txt
#  extracting: /tmp/val_labels/image_0770.txt
#  extracting: /tmp/val_labels/image_0757.txt
#  extracting: /tmp/val_labels/image_0719.txt
#  extracting: /tmp/val_labels/image_0750.txt
#  extracting: /tmp/val_labels/image_0763.txt
#  extracting: /tmp/val_labels/image_0756.txt
#  extracting: /tmp/val_labels/image_0739.txt
#  extracting: /tmp/val_labels/image_0760.txt
#  extracting: /tmp/val_labels/image_0751.txt
#  extracting: /tmp/val_labels/image_0723.txt
#  extracting: /tmp/val_labels/image_0749.txt
#  extracting: /tmp/val_labels/image_0741.txt
#  extracting: /tmp/val_labels/image_0726.txt
#  extracting: /tmp/val_labels/image_0775.txt
#  extracting: /tmp/val_labels/image_0735.txt
#  extracting: /tmp/val_labels/image_0759.txt
#  extracting: /tmp/val_labels/image_0776.txt
#  extracting: /tmp/val_labels/image_0710.txt
#  extracting: /tmp/val_labels/image_0755.txt
#  extracting: /tmp/val_labels/image_0769.txt
#  extracting: /tmp/val_labels/image_0712.txt
#  extracting: /tmp/val_labels/image_0752.txt
#  extracting: /tmp/val_labels/image_0765.txt
#  extracting: /tmp/val_labels/image_0730.txt
#  extracting: /tmp/val_labels/image_0736.txt
#  extracting: /tmp/val_labels/image_0754.txt
#  extracting: /tmp/val_labels/image_0771.txt
#  extracting: /tmp/val_labels/image_0742.txt
#  extracting: /tmp/val_labels/image_0780.txt
#  extracting: /tmp/val_labels/image_0772.txt
#  extracting: /tmp/val_labels/image_0779.txt
#  extracting: /tmp/val_labels/image_0729.txt
#  extracting: /tmp/val_labels/image_0718.txt
#  extracting: /tmp/val_labels/image_0716.txt
#  extracting: /tmp/val_labels/image_0721.txt
#  extracting: /tmp/val_labels/image_0714.txt
#  extracting: /tmp/val_labels/image_0720.txt
#  extracting: /tmp/val_labels/image_0762.txt
#  extracting: /tmp/val_labels/image_0743.txt
#  extracting: /tmp/val_labels/image_0727.txt
#  extracting: /tmp/val_labels/image_0722.txt
#  extracting: /tmp/val_labels/image_0715.txt
#  extracting: /tmp/val_labels/image_0766.txt
#  extracting: /tmp/val_labels/image_0732.txt
#  extracting: /tmp/val_labels/image_0724.txt
#  extracting: /tmp/val_labels/image_0768.txt
#  extracting: /tmp/val_labels/image_0773.txt
#  extracting: /tmp/val_labels/image_0728.txt
#  extracting: /tmp/val_labels/image_0758.txt
#  extracting: /tmp/val_labels/image_0781.txt
#  extracting: /tmp/val_labels/image_0796.txt
#  extracting: /tmp/val_labels/image_0789.txt
#  extracting: /tmp/val_labels/image_0797.txt
#  extracting: /tmp/val_labels/image_0794.txt
#  extracting: /tmp/val_labels/image_0792.txt
#  extracting: /tmp/val_labels/image_0784.txt
#  extracting: /tmp/val_labels/image_0790.txt
#  extracting: /tmp/val_labels/image_0783.txt
#  extracting: /tmp/val_labels/image_0788.txt
#  extracting: /tmp/val_labels/image_0791.txt
#  extracting: /tmp/val_labels/image_0798.txt
#  extracting: /tmp/val_labels/image_0799.txt
#  extracting: /tmp/val_labels/image_0786.txt
#  extracting: /tmp/val_labels/image_0782.txt
#  extracting: /tmp/val_labels/image_0793.txt
#  extracting: /tmp/val_labels/image_0795.txt
#  extracting: /tmp/val_labels/image_0787.txt
#  extracting: /tmp/val_labels/image_0785.txt

# %%
# !unzip "../../datasets/BrainHack TIL-23 OD _ ReID Novice/Test.zip" -d "/tmp/test_images"

# !unzip "../../datasets/BrainHack TIL-23 OD _ ReID Novice/suspects.zip" -d "/tmp/suspects"
# Out:
# Archive:  ../../datasets/BrainHack TIL-23 OD _ ReID Novice/Test.zip
#  extracting: /tmp/test_images/image_0612.png
#  extracting: /tmp/test_images/image_0602.png
#  extracting: /tmp/test_images/image_0658.png
#  extracting: /tmp/test_images/image_0636.png
#  extracting: /tmp/test_images/image_0582.png
#  extracting: /tmp/test_images/image_0651.png
#  extracting: /tmp/test_images/image_0623.png
#  extracting: /tmp/test_images/image_0598.png
#  extracting: /tmp/test_images/image_0647.png
#  extracting: /tmp/test_images/image_0604.png
#  extracting: /tmp/test_images/image_0631.png
#  extracting: /tmp/test_images/image_0640.png
#  extracting: /tmp/test_images/image_0597.png
#  extracting: /tmp/test_images/image_0643.png
#  extracting: /tmp/test_images/image_0614.png
#  extracting: /tmp/test_images/image_0642.png
#  extracting: /tmp/test_images/image_0618.png
#  extracting: /tmp/test_images/image_0667.png
#  extracting: /tmp/test_images/image_0666.png
#  extracting: /tmp/test_images/image_0663.png
#  extracting: /tmp/test_images/image_0650.png
#  extracting: /tmp/test_images/image_0600.png
#  extracting: /tmp/test_images/image_0641.png
#  extracting: /tmp/test_images/image_0589.png
#  extracting: /tmp/test_images/image_0621.png
#  extracting: /tmp/test_images/image_0605.png
#  extracting: /tmp/test_images/image_0661.png
#  extracting: /tmp/test_images/image_0648.png
#  extracting: /tmp/test_images/image_0620.png
#  extracting: /tmp/test_images/image_0599.png
#  extracting: /tmp/test_images/image_0591.png
#  extracting: /tmp/test_images/image_0655.png
#  extracting: /tmp/test_images/image_0629.png
#  extracting: /tmp/test_images/image_0656.png
#  extracting: /tmp/test_images/image_0659.png
#  extracting: /tmp/test_images/image_0607.png
#  extracting: /tmp/test_images/image_0592.png
#  extracting: /tmp/test_images/image_0616.png
#  extracting: /tmp/test_images/image_0624.png
#  extracting: /tmp/test_images/image_0625.png
#  extracting: /tmp/test_images/image_0633.png
#  extracting: /tmp/test_images/image_0634.png
#  extracting: /tmp/test_images/image_0595.png
#  extracting: /tmp/test_images/image_0654.png
#  extracting: /tmp/test_images/image_0588.png
#  extracting: /tmp/test_images/image_0637.png
#  extracting: /tmp/test_images/image_0644.png
#  extracting: /tmp/test_images/image_0630.png
#  extracting: /tmp/test_images/image_0646.png
#  extracting: /tmp/test_images/image_0664.png
#  extracting: /tmp/test_images/image_0645.png
#  extracting: /tmp/test_images/image_0626.png
#  extracting: /tmp/test_images/image_0606.png
#  extracting: /tmp/test_images/image_0649.png
#  extracting: /tmp/test_images/image_0657.png
#  extracting: /tmp/test_images/image_0611.png
#  extracting: /tmp/test_images/image_0590.png
#  extracting: /tmp/test_images/image_0665.png
#  extracting: /tmp/test_images/image_0652.png
#  extracting: /tmp/test_images/image_0596.png
#  extracting: /tmp/test_images/image_0617.png
#  extracting: /tmp/test_images/image_0609.png
#  extracting: /tmp/test_images/image_0638.png
#  extracting: /tmp/test_images/image_0660.png
#  extracting: /tmp/test_images/image_0619.png
#  extracting: /tmp/test_images/image_0608.png
#  extracting: /tmp/test_images/image_0593.png
#  extracting: /tmp/test_images/image_0627.png
#  extracting: /tmp/test_images/image_0717.png
#  extracting: /tmp/test_images/image_0677.png
#  extracting: /tmp/test_images/image_0682.png
#  extracting: /tmp/test_images/image_0744.png
#  extracting: /tmp/test_images/image_0702.png
#  extracting: /tmp/test_images/image_0669.png
#  extracting: /tmp/test_images/image_0745.png
#  extracting: /tmp/test_images/image_0673.png
#  extracting: /tmp/test_images/image_0730.png
#  extracting: /tmp/test_images/image_0694.png
#  extracting: /tmp/test_images/image_0712.png
#  extracting: /tmp/test_images/image_0699.png
#  extracting: /tmp/test_images/image_0691.png
#  extracting: /tmp/test_images/image_0723.png
#  extracting: /tmp/test_images/image_0736.png
#  extracting: /tmp/test_images/image_0696.png
#  extracting: /tmp/test_images/image_0709.png
#  extracting: /tmp/test_images/image_0725.png
#  extracting: /tmp/test_images/image_0683.png
#  extracting: /tmp/test_images/image_0674.png
#  extracting: /tmp/test_images/image_0693.png
#  extracting: /tmp/test_images/image_0692.png
#  extracting: /tmp/test_images/image_0680.png
#  extracting: /tmp/test_images/image_0698.png
#  extracting: /tmp/test_images/image_0737.png
#  extracting: /tmp/test_images/image_0670.png
#  extracting: /tmp/test_images/image_0714.png
#  extracting: /tmp/test_images/image_0684.png
#  extracting: /tmp/test_images/image_0721.png
#  extracting: /tmp/test_images/image_0715.png
#  extracting: /tmp/test_images/image_0746.png
#  extracting: /tmp/test_images/image_0672.png
#  extracting: /tmp/test_images/image_0724.png
#  extracting: /tmp/test_images/image_0728.png
#  extracting: /tmp/test_images/image_0690.png
#  extracting: /tmp/test_images/image_0681.png
#  extracting: /tmp/test_images/image_0740.png
#  extracting: /tmp/test_images/image_0708.png
#  extracting: /tmp/test_images/image_0726.png
#  extracting: /tmp/test_images/image_0695.png
#  extracting: /tmp/test_images/image_0686.png
#  extracting: /tmp/test_images/image_0729.png
#  extracting: /tmp/test_images/image_0710.png
#  extracting: /tmp/test_images/image_0678.png
#  extracting: /tmp/test_images/image_0722.png
#  extracting: /tmp/test_images/image_0716.png
#  extracting: /tmp/test_images/image_0675.png
#  extracting: /tmp/test_images/image_0697.png
#  extracting: /tmp/test_images/image_0685.png
#  extracting: /tmp/test_images/image_0706.png
#  extracting: /tmp/test_images/image_0731.png
#  extracting: /tmp/test_images/image_0727.png
#  extracting: /tmp/test_images/image_0704.png
#  extracting: /tmp/test_images/image_0734.png
#  extracting: /tmp/test_images/image_0747.png
#  extracting: /tmp/test_images/image_0752.png
#  extracting: /tmp/test_images/image_0688.png
#  extracting: /tmp/test_images/image_0713.png
#  extracting: /tmp/test_images/image_0720.png
#  extracting: /tmp/test_images/image_0668.png
#  extracting: /tmp/test_images/image_0739.png
#  extracting: /tmp/test_images/image_0738.png
#  extracting: /tmp/test_images/image_0749.png
#  extracting: /tmp/test_images/image_0750.png
#  extracting: /tmp/test_images/image_0671.png
#  extracting: /tmp/test_images/image_0703.png
#  extracting: /tmp/test_images/image_0700.png
#  extracting: /tmp/test_images/image_0707.png
#  extracting: /tmp/test_images/image_0689.png
#  extracting: /tmp/test_images/image_0732.png
#  extracting: /tmp/test_images/image_0733.png
#  extracting: /tmp/test_images/image_0743.png
#  extracting: /tmp/test_images/image_0711.png
#  extracting: /tmp/test_images/image_0741.png
#  extracting: /tmp/test_images/image_0719.png
#  extracting: /tmp/test_images/image_0742.png
#  extracting: /tmp/test_images/image_0676.png
#  extracting: /tmp/test_images/image_0751.png
#  extracting: /tmp/test_images/image_0679.png
#  extracting: /tmp/test_images/image_0705.png
#  extracting: /tmp/test_images/image_0687.png
#  extracting: /tmp/test_images/image_0735.png
#  extracting: /tmp/test_images/image_0718.png
#  extracting: /tmp/test_images/image_0701.png
#  extracting: /tmp/test_images/image_0748.png
#  extracting: /tmp/test_images/image_0762.png
#  extracting: /tmp/test_images/image_0837.png
#  extracting: /tmp/test_images/image_0759.png
#  extracting: /tmp/test_images/image_0808.png
#  extracting: /tmp/test_images/image_0784.png
#  extracting: /tmp/test_images/image_0787.png
#  extracting: /tmp/test_images/image_0816.png
#  extracting: /tmp/test_images/image_0789.png
#  extracting: /tmp/test_images/image_0819.png
#  extracting: /tmp/test_images/image_0757.png
#  extracting: /tmp/test_images/image_0834.png
#  extracting: /tmp/test_images/image_0818.png
#  extracting: /tmp/test_images/image_0793.png
#  extracting: /tmp/test_images/image_0801.png
#  extracting: /tmp/test_images/image_0764.png
#  extracting: /tmp/test_images/image_0829.png
#  extracting: /tmp/test_images/image_0763.png
#  extracting: /tmp/test_images/image_0791.png
#  extracting: /tmp/test_images/image_0796.png
#  extracting: /tmp/test_images/image_0822.png
#  extracting: /tmp/test_images/image_0767.png
#  extracting: /tmp/test_images/image_0839.png
#  extracting: /tmp/test_images/image_0785.png
#  extracting: /tmp/test_images/image_0832.png
#  extracting: /tmp/test_images/image_0782.png
#  extracting: /tmp/test_images/image_0753.png
#  extracting: /tmp/test_images/image_0779.png
#  extracting: /tmp/test_images/image_0788.png
#  extracting: /tmp/test_images/image_0798.png
#  extracting: /tmp/test_images/image_0772.png
#  extracting: /tmp/test_images/image_0766.png
#  extracting: /tmp/test_images/image_0817.png
#  extracting: /tmp/test_images/image_0805.png
#  extracting: /tmp/test_images/image_0770.png
#  extracting: /tmp/test_images/image_0823.png
#  extracting: /tmp/test_images/image_0761.png
#  extracting: /tmp/test_images/image_0774.png
#  extracting: /tmp/test_images/image_0809.png
#  extracting: /tmp/test_images/image_0799.png
#  extracting: /tmp/test_images/image_0765.png
#  extracting: /tmp/test_images/image_0833.png
#  extracting: /tmp/test_images/image_0820.png
#  extracting: /tmp/test_images/image_0836.png
#  extracting: /tmp/test_images/image_0813.png
#  extracting: /tmp/test_images/image_0758.png
#  extracting: /tmp/test_images/image_0781.png
#  extracting: /tmp/test_images/image_0786.png
#  extracting: /tmp/test_images/image_0778.png
#  extracting: /tmp/test_images/image_0773.png
#  extracting: /tmp/test_images/image_0815.png
#  extracting: /tmp/test_images/image_0800.png
#  extracting: /tmp/test_images/image_0768.png
#  extracting: /tmp/test_images/image_0824.png
#  extracting: /tmp/test_images/image_0760.png
#  extracting: /tmp/test_images/image_0806.png
#  extracting: /tmp/test_images/image_0783.png
#  extracting: /tmp/test_images/image_0790.png
#  extracting: /tmp/test_images/image_0797.png
#  extracting: /tmp/test_images/image_0755.png
#  extracting: /tmp/test_images/image_0769.png
#  extracting: /tmp/test_images/image_0830.png
#  extracting: /tmp/test_images/image_0812.png
#  extracting: /tmp/test_images/image_0803.png
#  extracting: /tmp/test_images/image_0814.png
#  extracting: /tmp/test_images/image_0802.png
#  extracting: /tmp/test_images/image_0831.png
#  extracting: /tmp/test_images/image_0825.png
#  extracting: /tmp/test_images/image_0792.png
#  extracting: /tmp/test_images/image_0804.png
#  extracting: /tmp/test_images/image_0780.png
#  extracting: /tmp/test_images/image_0807.png
#  extracting: /tmp/test_images/image_0811.png
#  extracting: /tmp/test_images/image_0756.png
#  extracting: /tmp/test_images/image_0775.png
#  extracting: /tmp/test_images/image_0821.png
#  extracting: /tmp/test_images/image_0826.png
#  extracting: /tmp/test_images/image_0771.png
#  extracting: /tmp/test_images/image_0838.png
#  extracting: /tmp/test_images/image_0794.png
#  extracting: /tmp/test_images/image_0777.png
#  extracting: /tmp/test_images/image_0828.png
#  extracting: /tmp/test_images/image_0776.png
#  extracting: /tmp/test_images/image_0754.png
#  extracting: /tmp/test_images/image_0795.png
#  extracting: /tmp/test_images/image_0810.png
#  extracting: /tmp/test_images/image_0827.png
#  extracting: /tmp/test_images/image_0835.png
#  extracting: /tmp/test_images/image_0849.png
#  extracting: /tmp/test_images/image_0892.png
#  extracting: /tmp/test_images/image_0857.png
#  extracting: /tmp/test_images/image_0865.png
#  extracting: /tmp/test_images/image_0909.png
#  extracting: /tmp/test_images/image_0861.png
#  extracting: /tmp/test_images/image_0854.png
#  extracting: /tmp/test_images/image_0904.png
#  extracting: /tmp/test_images/image_0850.png
#  extracting: /tmp/test_images/image_0898.png
#  extracting: /tmp/test_images/image_0879.png
#  extracting: /tmp/test_images/image_0922.png
#  extracting: /tmp/test_images/image_0916.png
#  extracting: /tmp/test_images/image_0881.png
#  extracting: /tmp/test_images/image_0875.png
#  extracting: /tmp/test_images/image_0911.png
#  extracting: /tmp/test_images/image_0867.png
#  extracting: /tmp/test_images/image_0890.png
#  extracting: /tmp/test_images/image_0906.png
#  extracting: /tmp/test_images/image_0918.png
#  extracting: /tmp/test_images/image_0886.png
#  extracting: /tmp/test_images/image_0864.png
#  extracting: /tmp/test_images/image_0893.png
#  extracting: /tmp/test_images/image_0872.png
#  extracting: /tmp/test_images/image_0901.png
#  extracting: /tmp/test_images/image_0889.png
#  extracting: /tmp/test_images/image_0845.png
#  extracting: /tmp/test_images/image_0853.png
#  extracting: /tmp/test_images/image_0855.png
#  extracting: /tmp/test_images/image_0895.png
#  extracting: /tmp/test_images/image_0885.png
#  extracting: /tmp/test_images/image_0921.png
#  extracting: /tmp/test_images/image_0882.png
#  extracting: /tmp/test_images/image_0899.png
#  extracting: /tmp/test_images/image_0858.png
#  extracting: /tmp/test_images/image_0919.png
#  extracting: /tmp/test_images/image_0887.png
#  extracting: /tmp/test_images/image_0896.png
#  extracting: /tmp/test_images/image_0877.png
#  extracting: /tmp/test_images/image_0869.png
#  extracting: /tmp/test_images/image_0847.png
#  extracting: /tmp/test_images/image_0848.png
#  extracting: /tmp/test_images/image_0914.png
#  extracting: /tmp/test_images/image_0912.png
#  extracting: /tmp/test_images/image_0860.png
#  extracting: /tmp/test_images/image_0883.png
#  extracting: /tmp/test_images/image_0856.png
#  extracting: /tmp/test_images/image_0902.png
#  extracting: /tmp/test_images/image_0876.png
#  extracting: /tmp/test_images/image_0866.png
#  extracting: /tmp/test_images/image_0884.png
#  extracting: /tmp/test_images/image_0891.png
#  extracting: /tmp/test_images/image_0851.png
#  extracting: /tmp/test_images/image_0880.png
#  extracting: /tmp/test_images/image_0915.png
#  extracting: /tmp/test_images/image_0842.png
#  extracting: /tmp/test_images/image_0924.png
#  extracting: /tmp/test_images/image_0846.png
#  extracting: /tmp/test_images/image_0862.png
#  extracting: /tmp/test_images/image_0900.png
#  extracting: /tmp/test_images/image_0894.png
#  extracting: /tmp/test_images/image_0878.png
#  extracting: /tmp/test_images/image_0920.png
#  extracting: /tmp/test_images/image_0888.png
#  extracting: /tmp/test_images/image_0841.png
#  extracting: /tmp/test_images/image_0897.png
#  extracting: /tmp/test_images/image_0871.png
#  extracting: /tmp/test_images/image_0905.png
#  extracting: /tmp/test_images/image_0908.png
#  extracting: /tmp/test_images/image_0844.png
#  extracting: /tmp/test_images/image_0917.png
#  extracting: /tmp/test_images/image_0907.png
#  extracting: /tmp/test_images/image_0852.png
#  extracting: /tmp/test_images/image_0840.png
#  extracting: /tmp/test_images/image_0903.png
#  extracting: /tmp/test_images/image_0913.png
#  extracting: /tmp/test_images/image_0863.png
#  extracting: /tmp/test_images/image_0873.png
#  extracting: /tmp/test_images/image_0874.png
#  extracting: /tmp/test_images/image_0843.png
#  extracting: /tmp/test_images/image_0859.png
#  extracting: /tmp/test_images/image_0923.png
#  extracting: /tmp/test_images/image_0870.png
#  extracting: /tmp/test_images/image_0910.png
#  extracting: /tmp/test_images/image_0868.png
#  extracting: /tmp/test_images/image_0937.png
#  extracting: /tmp/test_images/image_0982.png
#  extracting: /tmp/test_images/image_0958.png
#  extracting: /tmp/test_images/image_0984.png
#  extracting: /tmp/test_images/image_0995.png
#  extracting: /tmp/test_images/image_0931.png
#  extracting: /tmp/test_images/image_0953.png
#  extracting: /tmp/test_images/image_0968.png
#  extracting: /tmp/test_images/image_0993.png
#  extracting: /tmp/test_images/image_0998.png
#  extracting: /tmp/test_images/image_0976.png
#  extracting: /tmp/test_images/image_1007.png
#  extracting: /tmp/test_images/image_0929.png
#  extracting: /tmp/test_images/image_0951.png
#  extracting: /tmp/test_images/image_1005.png
#  extracting: /tmp/test_images/image_0925.png
#  extracting: /tmp/test_images/image_0955.png
#  extracting: /tmp/test_images/image_0989.png
#  extracting: /tmp/test_images/image_1003.png
#  extracting: /tmp/test_images/image_0936.png
#  extracting: /tmp/test_images/image_0994.png
#  extracting: /tmp/test_images/image_1000.png
#  extracting: /tmp/test_images/image_0996.png
#  extracting: /tmp/test_images/image_0979.png
#  extracting: /tmp/test_images/image_0966.png
#  extracting: /tmp/test_images/image_0972.png
#  extracting: /tmp/test_images/image_0988.png
#  extracting: /tmp/test_images/image_0963.png
#  extracting: /tmp/test_images/image_0962.png
#  extracting: /tmp/test_images/image_0938.png
#  extracting: /tmp/test_images/image_0987.png
#  extracting: /tmp/test_images/image_1004.png
#  extracting: /tmp/test_images/image_0974.png
#  extracting: /tmp/test_images/image_0950.png
#  extracting: /tmp/test_images/image_1006.png
#  extracting: /tmp/test_images/image_0946.png
#  extracting: /tmp/test_images/image_0961.png
#  extracting: /tmp/test_images/image_0983.png
#  extracting: /tmp/test_images/image_1011.png
#  extracting: /tmp/test_images/image_0930.png
#  extracting: /tmp/test_images/image_0967.png
#  extracting: /tmp/test_images/image_0943.png
#  extracting: /tmp/test_images/image_0957.png
#  extracting: /tmp/test_images/image_0971.png
#  extracting: /tmp/test_images/image_0992.png
#  extracting: /tmp/test_images/image_1001.png
#  extracting: /tmp/test_images/image_0991.png
#  extracting: /tmp/test_images/image_0944.png
#  extracting: /tmp/test_images/image_0999.png
#  extracting: /tmp/test_images/image_0973.png
#  extracting: /tmp/test_images/image_0954.png
#  extracting: /tmp/test_images/image_0945.png
#  extracting: /tmp/test_images/image_0969.png
#  extracting: /tmp/test_images/image_0933.png
#  extracting: /tmp/test_images/image_0941.png
#  extracting: /tmp/test_images/image_0940.png
#  extracting: /tmp/test_images/image_0997.png
#  extracting: /tmp/test_images/image_0990.png
#  extracting: /tmp/test_images/image_0978.png
#  extracting: /tmp/test_images/image_0986.png
#  extracting: /tmp/test_images/image_1009.png
#  extracting: /tmp/test_images/image_0952.png
#  extracting: /tmp/test_images/image_0927.png
#  extracting: /tmp/test_images/image_0948.png
#  extracting: /tmp/test_images/image_0928.png
#  extracting: /tmp/test_images/image_0942.png
#  extracting: /tmp/test_images/image_0939.png
#  extracting: /tmp/test_images/image_0947.png
#  extracting: /tmp/test_images/image_0965.png
#  extracting: /tmp/test_images/image_0960.png
#  extracting: /tmp/test_images/image_1010.png
#  extracting: /tmp/test_images/image_0959.png
#  extracting: /tmp/test_images/image_0970.png
#  extracting: /tmp/test_images/image_0935.png
#  extracting: /tmp/test_images/image_0934.png
#  extracting: /tmp/test_images/image_0981.png
#  extracting: /tmp/test_images/image_0964.png
#  extracting: /tmp/test_images/image_0980.png
#  extracting: /tmp/test_images/image_1002.png
#  extracting: /tmp/test_images/image_0985.png
#  extracting: /tmp/test_images/image_0949.png
#  extracting: /tmp/test_images/image_0956.png
#  extracting: /tmp/test_images/image_0926.png
#  extracting: /tmp/test_images/image_1008.png
#  extracting: /tmp/test_images/image_0975.png
#  extracting: /tmp/test_images/image_0932.png
#  extracting: /tmp/test_images/image_0977.png
#  extracting: /tmp/test_images/image_1016.png
#  extracting: /tmp/test_images/image_1015.png
#  extracting: /tmp/test_images/image_1066.png
#  extracting: /tmp/test_images/image_1069.png
#  extracting: /tmp/test_images/image_1046.png
#  extracting: /tmp/test_images/image_1052.png
#  extracting: /tmp/test_images/image_1092.png
#  extracting: /tmp/test_images/image_1065.png
#  extracting: /tmp/test_images/image_1037.png
#  extracting: /tmp/test_images/image_1081.png
#  extracting: /tmp/test_images/image_1040.png
#  extracting: /tmp/test_images/image_1089.png
#  extracting: /tmp/test_images/image_1012.png
#  extracting: /tmp/test_images/image_1035.png
#  extracting: /tmp/test_images/image_1068.png
#  extracting: /tmp/test_images/image_1014.png
#  extracting: /tmp/test_images/image_1030.png
#  extracting: /tmp/test_images/image_1017.png
#  extracting: /tmp/test_images/image_1071.png
#  extracting: /tmp/test_images/image_1048.png
#  extracting: /tmp/test_images/image_1044.png
#  extracting: /tmp/test_images/image_1061.png
#  extracting: /tmp/test_images/image_1021.png
#  extracting: /tmp/test_images/image_1088.png
#  extracting: /tmp/test_images/image_1087.png
#  extracting: /tmp/test_images/image_1024.png
#  extracting: /tmp/test_images/image_1098.png
#  extracting: /tmp/test_images/image_1067.png
#  extracting: /tmp/test_images/image_1085.png
#  extracting: /tmp/test_images/image_1078.png
#  extracting: /tmp/test_images/image_1018.png
#  extracting: /tmp/test_images/image_1060.png
#  extracting: /tmp/test_images/image_1028.png
#  extracting: /tmp/test_images/image_1074.png
#  extracting: /tmp/test_images/image_1083.png
#  extracting: /tmp/test_images/image_1051.png
#  extracting: /tmp/test_images/image_1086.png
#  extracting: /tmp/test_images/image_1096.png
#  extracting: /tmp/test_images/image_1055.png
#  extracting: /tmp/test_images/image_1057.png
#  extracting: /tmp/test_images/image_1082.png
#  extracting: /tmp/test_images/image_1022.png
#  extracting: /tmp/test_images/image_1050.png
#  extracting: /tmp/test_images/image_1062.png
#  extracting: /tmp/test_images/image_1073.png
#  extracting: /tmp/test_images/image_1093.png
#  extracting: /tmp/test_images/image_1019.png
#  extracting: /tmp/test_images/image_1013.png
#  extracting: /tmp/test_images/image_1056.png
#  extracting: /tmp/test_images/image_1079.png
#  extracting: /tmp/test_images/image_1045.png
#  extracting: /tmp/test_images/image_1058.png
#  extracting: /tmp/test_images/image_1032.png
#  extracting: /tmp/test_images/image_1033.png
#  extracting: /tmp/test_images/image_1090.png
#  extracting: /tmp/test_images/image_1039.png
#  extracting: /tmp/test_images/image_1063.png
#  extracting: /tmp/test_images/image_1041.png
#  extracting: /tmp/test_images/image_1070.png
#  extracting: /tmp/test_images/image_1072.png
#  extracting: /tmp/test_images/image_1091.png
#  extracting: /tmp/test_images/image_1059.png
#  extracting: /tmp/test_images/image_1076.png
#  extracting: /tmp/test_images/image_1053.png
#  extracting: /tmp/test_images/image_1097.png
#  extracting: /tmp/test_images/image_1095.png
#  extracting: /tmp/test_images/image_1075.png
#  extracting: /tmp/test_images/image_1094.png
#  extracting: /tmp/test_images/image_1027.png
#  extracting: /tmp/test_images/image_1025.png
#  extracting: /tmp/test_images/image_1034.png
#  extracting: /tmp/test_images/image_1042.png
#  extracting: /tmp/test_images/image_1077.png
#  extracting: /tmp/test_images/image_1084.png
#  extracting: /tmp/test_images/image_1080.png
#  extracting: /tmp/test_images/image_1054.png
#  extracting: /tmp/test_images/image_1038.png
#  extracting: /tmp/test_images/image_1043.png
#  extracting: /tmp/test_images/image_1029.png
#  extracting: /tmp/test_images/image_1036.png
#  extracting: /tmp/test_images/image_1026.png
#  extracting: /tmp/test_images/image_1020.png
#  extracting: /tmp/test_images/image_1047.png
#  extracting: /tmp/test_images/image_1023.png
#  extracting: /tmp/test_images/image_1049.png
#  extracting: /tmp/test_images/image_1064.png
#  extracting: /tmp/test_images/image_1031.png
#  extracting: /tmp/test_images/image_1152.png
#  extracting: /tmp/test_images/image_1140.png
#  extracting: /tmp/test_images/image_1106.png
#  extracting: /tmp/test_images/image_1142.png
#  extracting: /tmp/test_images/image_1110.png
#  extracting: /tmp/test_images/image_1176.png
#  extracting: /tmp/test_images/image_1118.png
#  extracting: /tmp/test_images/image_1107.png
#  extracting: /tmp/test_images/image_1126.png
#  extracting: /tmp/test_images/image_1143.png
#  extracting: /tmp/test_images/image_1161.png
#  extracting: /tmp/test_images/image_1138.png
#  extracting: /tmp/test_images/image_1116.png
#  extracting: /tmp/test_images/image_1172.png
#  extracting: /tmp/test_images/image_1147.png
#  extracting: /tmp/test_images/image_1185.png
#  extracting: /tmp/test_images/image_1130.png
#  extracting: /tmp/test_images/image_1112.png
#  extracting: /tmp/test_images/image_1169.png
#  extracting: /tmp/test_images/image_1162.png
#  extracting: /tmp/test_images/image_1136.png
#  extracting: /tmp/test_images/image_1105.png
#  extracting: /tmp/test_images/image_1141.png
#  extracting: /tmp/test_images/image_1164.png
#  extracting: /tmp/test_images/image_1155.png
#  extracting: /tmp/test_images/image_1128.png
#  extracting: /tmp/test_images/image_1119.png
#  extracting: /tmp/test_images/image_1145.png
#  extracting: /tmp/test_images/image_1160.png
#  extracting: /tmp/test_images/image_1163.png
#  extracting: /tmp/test_images/image_1156.png
#  extracting: /tmp/test_images/image_1174.png
#  extracting: /tmp/test_images/image_1101.png
#  extracting: /tmp/test_images/image_1170.png
#  extracting: /tmp/test_images/image_1135.png
#  extracting: /tmp/test_images/image_1182.png
#  extracting: /tmp/test_images/image_1177.png
#  extracting: /tmp/test_images/image_1166.png
#  extracting: /tmp/test_images/image_1103.png
#  extracting: /tmp/test_images/image_1149.png
#  extracting: /tmp/test_images/image_1121.png
#  extracting: /tmp/test_images/image_1100.png
#  extracting: /tmp/test_images/image_1146.png
#  extracting: /tmp/test_images/image_1165.png
#  extracting: /tmp/test_images/image_1134.png
#  extracting: /tmp/test_images/image_1102.png
#  extracting: /tmp/test_images/image_1133.png
#  extracting: /tmp/test_images/image_1179.png
#  extracting: /tmp/test_images/image_1113.png
#  extracting: /tmp/test_images/image_1111.png
#  extracting: /tmp/test_images/image_1123.png
#  extracting: /tmp/test_images/image_1108.png
#  extracting: /tmp/test_images/image_1127.png
#  extracting: /tmp/test_images/image_1168.png
#  extracting: /tmp/test_images/image_1175.png
#  extracting: /tmp/test_images/image_1186.png
#  extracting: /tmp/test_images/image_1139.png
#  extracting: /tmp/test_images/image_1129.png
#  extracting: /tmp/test_images/image_1114.png
#  extracting: /tmp/test_images/image_1151.png
#  extracting: /tmp/test_images/image_1104.png
#  extracting: /tmp/test_images/image_1150.png
#  extracting: /tmp/test_images/image_1099.png
#  extracting: /tmp/test_images/image_1124.png
#  extracting: /tmp/test_images/image_1120.png
#  extracting: /tmp/test_images/image_1171.png
#  extracting: /tmp/test_images/image_1158.png
#  extracting: /tmp/test_images/image_1117.png
#  extracting: /tmp/test_images/image_1131.png
#  extracting: /tmp/test_images/image_1181.png
#  extracting: /tmp/test_images/image_1154.png
#  extracting: /tmp/test_images/image_1157.png
#  extracting: /tmp/test_images/image_1109.png
#  extracting: /tmp/test_images/image_1153.png
#  extracting: /tmp/test_images/image_1122.png
#  extracting: /tmp/test_images/image_1178.png
#  extracting: /tmp/test_images/image_1183.png
#  extracting: /tmp/test_images/image_1125.png
#  extracting: /tmp/test_images/image_1115.png
#  extracting: /tmp/test_images/image_1137.png
#  extracting: /tmp/test_images/image_1148.png
#  extracting: /tmp/test_images/image_1180.png
#  extracting: /tmp/test_images/image_1132.png
#  extracting: /tmp/test_images/image_1144.png
#  extracting: /tmp/test_images/image_1184.png
#  extracting: /tmp/test_images/image_1173.png
#  extracting: /tmp/test_images/image_1167.png
#  extracting: /tmp/test_images/image_1159.png
#  extracting: /tmp/test_images/image_1236.png
#  extracting: /tmp/test_images/image_1242.png
#  extracting: /tmp/test_images/image_1253.png
#  extracting: /tmp/test_images/image_1252.png
#  extracting: /tmp/test_images/image_1250.png
#  extracting: /tmp/test_images/image_1195.png
#  extracting: /tmp/test_images/image_1197.png
#  extracting: /tmp/test_images/image_1199.png
#  extracting: /tmp/test_images/image_1235.png
#  extracting: /tmp/test_images/image_1200.png
#  extracting: /tmp/test_images/image_1223.png
#  extracting: /tmp/test_images/image_1209.png
#  extracting: /tmp/test_images/image_1229.png
#  extracting: /tmp/test_images/image_1228.png
#  extracting: /tmp/test_images/image_1206.png
#  extracting: /tmp/test_images/image_1190.png
#  extracting: /tmp/test_images/image_1203.png
#  extracting: /tmp/test_images/image_1244.png
#  extracting: /tmp/test_images/image_1273.png
#  extracting: /tmp/test_images/image_1216.png
#  extracting: /tmp/test_images/image_1208.png
#  extracting: /tmp/test_images/image_1204.png
#  extracting: /tmp/test_images/image_1272.png
#  extracting: /tmp/test_images/image_1267.png
#  extracting: /tmp/test_images/image_1241.png
#  extracting: /tmp/test_images/image_1198.png
#  extracting: /tmp/test_images/image_1189.png
#  extracting: /tmp/test_images/image_1257.png
#  extracting: /tmp/test_images/image_1232.png
#  extracting: /tmp/test_images/image_1268.png
#  extracting: /tmp/test_images/image_1237.png
#  extracting: /tmp/test_images/image_1274.png
#  extracting: /tmp/test_images/image_1246.png
#  extracting: /tmp/test_images/image_1238.png
#  extracting: /tmp/test_images/image_1256.png
#  extracting: /tmp/test_images/image_1207.png
#  extracting: /tmp/test_images/image_1212.png
#  extracting: /tmp/test_images/image_1201.png
#  extracting: /tmp/test_images/image_1239.png
#  extracting: /tmp/test_images/image_1217.png
#  extracting: /tmp/test_images/image_1196.png
#  extracting: /tmp/test_images/image_1192.png
#  extracting: /tmp/test_images/image_1275.png
#  extracting: /tmp/test_images/image_1263.png
#  extracting: /tmp/test_images/image_1221.png
#  extracting: /tmp/test_images/image_1219.png
#  extracting: /tmp/test_images/image_1210.png
#  extracting: /tmp/test_images/image_1225.png
#  extracting: /tmp/test_images/image_1222.png
#  extracting: /tmp/test_images/image_1202.png
#  extracting: /tmp/test_images/image_1226.png
#  extracting: /tmp/test_images/image_1231.png
#  extracting: /tmp/test_images/image_1211.png
#  extracting: /tmp/test_images/image_1266.png
#  extracting: /tmp/test_images/image_1271.png
#  extracting: /tmp/test_images/image_1214.png
#  extracting: /tmp/test_images/image_1262.png
#  extracting: /tmp/test_images/image_1255.png
#  extracting: /tmp/test_images/image_1265.png
#  extracting: /tmp/test_images/image_1270.png
#  extracting: /tmp/test_images/image_1245.png
#  extracting: /tmp/test_images/image_1213.png
#  extracting: /tmp/test_images/image_1233.png
#  extracting: /tmp/test_images/image_1224.png
#  extracting: /tmp/test_images/image_1240.png
#  extracting: /tmp/test_images/image_1259.png
#  extracting: /tmp/test_images/image_1234.png
#  extracting: /tmp/test_images/image_1215.png
#  extracting: /tmp/test_images/image_1251.png
#  extracting: /tmp/test_images/image_1260.png
#  extracting: /tmp/test_images/image_1249.png
#  extracting: /tmp/test_images/image_1248.png
#  extracting: /tmp/test_images/image_1261.png
#  extracting: /tmp/test_images/image_1218.png
#  extracting: /tmp/test_images/image_1269.png
#  extracting: /tmp/test_images/image_1258.png
#  extracting: /tmp/test_images/image_1254.png
#  extracting: /tmp/test_images/image_1264.png
#  extracting: /tmp/test_images/image_1194.png
#  extracting: /tmp/test_images/image_1205.png
#  extracting: /tmp/test_images/image_1193.png
#  extracting: /tmp/test_images/image_1191.png
#  extracting: /tmp/test_images/image_1188.png
#  extracting: /tmp/test_images/image_1227.png
#  extracting: /tmp/test_images/image_1187.png
#  extracting: /tmp/test_images/image_1247.png
#  extracting: /tmp/test_images/image_1230.png
#  extracting: /tmp/test_images/image_1243.png
#  extracting: /tmp/test_images/image_1220.png
#  extracting: /tmp/test_images/image_1284.png
#  extracting: /tmp/test_images/image_1327.png
#  extracting: /tmp/test_images/image_1364.png
#  extracting: /tmp/test_images/image_1292.png
#  extracting: /tmp/test_images/image_1279.png
#  extracting: /tmp/test_images/image_1357.png
#  extracting: /tmp/test_images/image_1347.png
#  extracting: /tmp/test_images/image_1291.png
#  extracting: /tmp/test_images/image_1351.png
#  extracting: /tmp/test_images/image_1345.png
#  extracting: /tmp/test_images/image_1344.png
#  extracting: /tmp/test_images/image_1281.png
#  extracting: /tmp/test_images/image_1319.png
#  extracting: /tmp/test_images/image_1355.png
#  extracting: /tmp/test_images/image_1336.png
#  extracting: /tmp/test_images/image_1325.png
#  extracting: /tmp/test_images/image_1309.png
#  extracting: /tmp/test_images/image_1353.png
#  extracting: /tmp/test_images/image_1329.png
#  extracting: /tmp/test_images/image_1308.png
#  extracting: /tmp/test_images/image_1332.png
#  extracting: /tmp/test_images/image_1314.png
#  extracting: /tmp/test_images/image_1311.png
#  extracting: /tmp/test_images/image_1320.png
#  extracting: /tmp/test_images/image_1323.png
#  extracting: /tmp/test_images/image_1287.png
#  extracting: /tmp/test_images/image_1288.png
#  extracting: /tmp/test_images/image_1294.png
#  extracting: /tmp/test_images/image_1283.png
#  extracting: /tmp/test_images/image_1298.png
#  extracting: /tmp/test_images/image_1305.png
#  extracting: /tmp/test_images/image_1361.png
#  extracting: /tmp/test_images/image_1313.png
#  extracting: /tmp/test_images/image_1358.png
#  extracting: /tmp/test_images/image_1343.png
#  extracting: /tmp/test_images/image_1278.png
#  extracting: /tmp/test_images/image_1312.png
#  extracting: /tmp/test_images/image_1346.png
#  extracting: /tmp/test_images/image_1297.png
#  extracting: /tmp/test_images/image_1317.png
#  extracting: /tmp/test_images/image_1362.png
#  extracting: /tmp/test_images/image_1348.png
#  extracting: /tmp/test_images/image_1315.png
#  extracting: /tmp/test_images/image_1334.png
#  extracting: /tmp/test_images/image_1302.png
#  extracting: /tmp/test_images/image_1328.png
#  extracting: /tmp/test_images/image_1359.png
#  extracting: /tmp/test_images/image_1321.png
#  extracting: /tmp/test_images/image_1286.png
#  extracting: /tmp/test_images/image_1333.png
#  extracting: /tmp/test_images/image_1303.png
#  extracting: /tmp/test_images/image_1301.png
#  extracting: /tmp/test_images/image_1356.png
#  extracting: /tmp/test_images/image_1342.png
#  extracting: /tmp/test_images/image_1349.png
#  extracting: /tmp/test_images/image_1340.png
#  extracting: /tmp/test_images/image_1293.png
#  extracting: /tmp/test_images/image_1326.png
#  extracting: /tmp/test_images/image_1322.png
#  extracting: /tmp/test_images/image_1296.png
#  extracting: /tmp/test_images/image_1280.png
#  extracting: /tmp/test_images/image_1316.png
#  extracting: /tmp/test_images/image_1306.png
#  extracting: /tmp/test_images/image_1350.png
#  extracting: /tmp/test_images/image_1339.png
#  extracting: /tmp/test_images/image_1300.png
#  extracting: /tmp/test_images/image_1324.png
#  extracting: /tmp/test_images/image_1276.png
#  extracting: /tmp/test_images/image_1366.png
#  extracting: /tmp/test_images/image_1363.png
#  extracting: /tmp/test_images/image_1304.png
#  extracting: /tmp/test_images/image_1282.png
#  extracting: /tmp/test_images/image_1310.png
#  extracting: /tmp/test_images/image_1335.png
#  extracting: /tmp/test_images/image_1318.png
#  extracting: /tmp/test_images/image_1307.png
#  extracting: /tmp/test_images/image_1295.png
#  extracting: /tmp/test_images/image_1352.png
#  extracting: /tmp/test_images/image_1285.png
#  extracting: /tmp/test_images/image_1289.png
#  extracting: /tmp/test_images/image_1331.png
#  extracting: /tmp/test_images/image_1360.png
#  extracting: /tmp/test_images/image_1365.png
#  extracting: /tmp/test_images/image_1290.png
#  extracting: /tmp/test_images/image_1277.png
#  extracting: /tmp/test_images/image_1299.png
#  extracting: /tmp/test_images/image_1354.png
#  extracting: /tmp/test_images/image_1338.png
#  extracting: /tmp/test_images/image_1341.png
#  extracting: /tmp/test_images/image_1337.png
#  extracting: /tmp/test_images/image_1330.png
#  extracting: /tmp/test_images/image_1441.png
#  extracting: /tmp/test_images/image_1422.png
#  extracting: /tmp/test_images/image_1387.png
#  extracting: /tmp/test_images/image_1412.png
#  extracting: /tmp/test_images/image_1431.png
#  extracting: /tmp/test_images/image_1399.png
#  extracting: /tmp/test_images/image_1385.png
#  extracting: /tmp/test_images/image_1403.png
#  extracting: /tmp/test_images/image_1418.png
#  extracting: /tmp/test_images/image_1448.png
#  extracting: /tmp/test_images/image_1374.png
#  extracting: /tmp/test_images/image_1450.png
#  extracting: /tmp/test_images/image_1444.png
#  extracting: /tmp/test_images/image_1416.png
#  extracting: /tmp/test_images/image_1417.png
#  extracting: /tmp/test_images/image_1370.png
#  extracting: /tmp/test_images/image_1371.png
#  extracting: /tmp/test_images/image_1402.png
#  extracting: /tmp/test_images/image_1440.png
#  extracting: /tmp/test_images/image_1393.png
#  extracting: /tmp/test_images/image_1435.png
#  extracting: /tmp/test_images/image_1426.png
#  extracting: /tmp/test_images/image_1367.png
#  extracting: /tmp/test_images/image_1419.png
#  extracting: /tmp/test_images/image_1383.png
#  extracting: /tmp/test_images/image_1372.png
#  extracting: /tmp/test_images/image_1381.png
#  extracting: /tmp/test_images/image_1392.png
#  extracting: /tmp/test_images/image_1377.png
#  extracting: /tmp/test_images/image_1409.png
#  extracting: /tmp/test_images/image_1454.png
#  extracting: /tmp/test_images/image_1415.png
#  extracting: /tmp/test_images/image_1432.png
#  extracting: /tmp/test_images/image_1373.png
#  extracting: /tmp/test_images/image_1368.png
#  extracting: /tmp/test_images/image_1425.png
#  extracting: /tmp/test_images/image_1388.png
#  extracting: /tmp/test_images/image_1427.png
#  extracting: /tmp/test_images/image_1421.png
#  extracting: /tmp/test_images/image_1446.png
#  extracting: /tmp/test_images/image_1404.png
#  extracting: /tmp/test_images/image_1369.png
#  extracting: /tmp/test_images/image_1423.png
#  extracting: /tmp/test_images/image_1396.png
#  extracting: /tmp/test_images/image_1378.png
#  extracting: /tmp/test_images/image_1455.png
#  extracting: /tmp/test_images/image_1434.png
#  extracting: /tmp/test_images/image_1451.png
#  extracting: /tmp/test_images/image_1438.png
#  extracting: /tmp/test_images/image_1380.png
#  extracting: /tmp/test_images/image_1437.png
#  extracting: /tmp/test_images/image_1420.png
#  extracting: /tmp/test_images/image_1406.png
#  extracting: /tmp/test_images/image_1452.png
#  extracting: /tmp/test_images/image_1397.png
#  extracting: /tmp/test_images/image_1390.png
#  extracting: /tmp/test_images/image_1410.png
#  extracting: /tmp/test_images/image_1414.png
#  extracting: /tmp/test_images/image_1428.png
#  extracting: /tmp/test_images/image_1395.png
#  extracting: /tmp/test_images/image_1424.png
#  extracting: /tmp/test_images/image_1436.png
#  extracting: /tmp/test_images/image_1375.png
#  extracting: /tmp/test_images/image_1398.png
#  extracting: /tmp/test_images/image_1376.png
#  extracting: /tmp/test_images/image_1407.png
#  extracting: /tmp/test_images/image_1413.png
#  extracting: /tmp/test_images/image_1433.png
#  extracting: /tmp/test_images/image_1384.png
#  extracting: /tmp/test_images/image_1401.png
#  extracting: /tmp/test_images/image_1430.png
#  extracting: /tmp/test_images/image_1443.png
#  extracting: /tmp/test_images/image_1382.png
#  extracting: /tmp/test_images/image_1429.png
#  extracting: /tmp/test_images/image_1453.png
#  extracting: /tmp/test_images/image_1379.png
#  extracting: /tmp/test_images/image_1411.png
#  extracting: /tmp/test_images/image_1445.png
#  extracting: /tmp/test_images/image_1456.png
#  extracting: /tmp/test_images/image_1447.png
#  extracting: /tmp/test_images/image_1394.png
#  extracting: /tmp/test_images/image_1400.png
#  extracting: /tmp/test_images/image_1386.png
#  extracting: /tmp/test_images/image_1391.png
#  extracting: /tmp/test_images/image_1405.png
#  extracting: /tmp/test_images/image_1439.png
#  extracting: /tmp/test_images/image_1449.png
#  extracting: /tmp/test_images/image_1389.png
#  extracting: /tmp/test_images/image_1408.png
#  extracting: /tmp/test_images/image_1442.png
#  extracting: /tmp/test_images/image_1457.png
#  extracting: /tmp/test_images/image_1488.png
#  extracting: /tmp/test_images/image_1544.png
#  extracting: /tmp/test_images/image_1464.png
#  extracting: /tmp/test_images/image_1494.png
#  extracting: /tmp/test_images/image_1503.png
#  extracting: /tmp/test_images/image_1508.png
#  extracting: /tmp/test_images/image_1520.png
#  extracting: /tmp/test_images/image_1461.png
#  extracting: /tmp/test_images/image_1524.png
#  extracting: /tmp/test_images/image_1496.png
#  extracting: /tmp/test_images/image_1530.png
#  extracting: /tmp/test_images/image_1510.png
#  extracting: /tmp/test_images/image_1546.png
#  extracting: /tmp/test_images/image_1465.png
#  extracting: /tmp/test_images/image_1542.png
#  extracting: /tmp/test_images/image_1536.png
#  extracting: /tmp/test_images/image_1498.png
#  extracting: /tmp/test_images/image_1486.png
#  extracting: /tmp/test_images/image_1540.png
#  extracting: /tmp/test_images/image_1502.png
#  extracting: /tmp/test_images/image_1480.png
#  extracting: /tmp/test_images/image_1477.png
#  extracting: /tmp/test_images/image_1476.png
#  extracting: /tmp/test_images/image_1521.png
#  extracting: /tmp/test_images/image_1534.png
#  extracting: /tmp/test_images/image_1472.png
#  extracting: /tmp/test_images/image_1484.png
#  extracting: /tmp/test_images/image_1522.png
#  extracting: /tmp/test_images/image_1466.png
#  extracting: /tmp/test_images/image_1471.png
#  extracting: /tmp/test_images/image_1478.png
#  extracting: /tmp/test_images/image_1475.png
#  extracting: /tmp/test_images/image_1501.png
#  extracting: /tmp/test_images/image_1513.png
#  extracting: /tmp/test_images/image_1531.png
#  extracting: /tmp/test_images/image_1499.png
#  extracting: /tmp/test_images/image_1482.png
#  extracting: /tmp/test_images/image_1483.png
#  extracting: /tmp/test_images/image_1537.png
#  extracting: /tmp/test_images/image_1467.png
#  extracting: /tmp/test_images/image_1529.png
#  extracting: /tmp/test_images/image_1509.png
#  extracting: /tmp/test_images/image_1528.png
#  extracting: /tmp/test_images/image_1538.png
#  extracting: /tmp/test_images/image_1495.png
#  extracting: /tmp/test_images/image_1527.png
#  extracting: /tmp/test_images/image_1490.png
#  extracting: /tmp/test_images/image_1491.png
#  extracting: /tmp/test_images/image_1469.png
#  extracting: /tmp/test_images/image_1517.png
#  extracting: /tmp/test_images/image_1460.png
#  extracting: /tmp/test_images/image_1514.png
#  extracting: /tmp/test_images/image_1506.png
#  extracting: /tmp/test_images/image_1470.png
#  extracting: /tmp/test_images/image_1474.png
#  extracting: /tmp/test_images/image_1547.png
#  extracting: /tmp/test_images/image_1479.png
#  extracting: /tmp/test_images/image_1541.png
#  extracting: /tmp/test_images/image_1458.png
#  extracting: /tmp/test_images/image_1500.png
#  extracting: /tmp/test_images/image_1505.png
#  extracting: /tmp/test_images/image_1515.png
#  extracting: /tmp/test_images/image_1462.png
#  extracting: /tmp/test_images/image_1463.png
#  extracting: /tmp/test_images/image_1535.png
#  extracting: /tmp/test_images/image_1487.png
#  extracting: /tmp/test_images/image_1532.png
#  extracting: /tmp/test_images/image_1511.png
#  extracting: /tmp/test_images/image_1468.png
#  extracting: /tmp/test_images/image_1516.png
#  extracting: /tmp/test_images/image_1459.png
#  extracting: /tmp/test_images/image_1525.png
#  extracting: /tmp/test_images/image_1481.png
#  extracting: /tmp/test_images/image_1492.png
#  extracting: /tmp/test_images/image_1526.png
#  extracting: /tmp/test_images/image_1504.png
#  extracting: /tmp/test_images/image_1493.png
#  extracting: /tmp/test_images/image_1539.png
#  extracting: /tmp/test_images/image_1543.png
#  extracting: /tmp/test_images/image_1533.png
#  extracting: /tmp/test_images/image_1523.png
#  extracting: /tmp/test_images/image_1489.png
#  extracting: /tmp/test_images/image_1545.png
#  extracting: /tmp/test_images/image_1507.png
#  extracting: /tmp/test_images/image_1485.png
#  extracting: /tmp/test_images/image_1519.png
#  extracting: /tmp/test_images/image_1548.png
#  extracting: /tmp/test_images/image_1497.png
#  extracting: /tmp/test_images/image_1473.png
#  extracting: /tmp/test_images/image_1512.png
#  extracting: /tmp/test_images/image_1518.png
#  extracting: /tmp/test_images/image_1583.png
#  extracting: /tmp/test_images/image_1559.png
#  extracting: /tmp/test_images/image_1568.png
#  extracting: /tmp/test_images/image_1572.png
#  extracting: /tmp/test_images/image_1577.png
#  extracting: /tmp/test_images/image_1587.png
#  extracting: /tmp/test_images/image_1590.png
#  extracting: /tmp/test_images/image_1582.png
#  extracting: /tmp/test_images/image_1573.png
#  extracting: /tmp/test_images/image_1566.png
#  extracting: /tmp/test_images/image_1591.png
#  extracting: /tmp/test_images/image_1578.png
#  extracting: /tmp/test_images/image_1579.png
#  extracting: /tmp/test_images/image_1575.png
#  extracting: /tmp/test_images/image_1598.png
#  extracting: /tmp/test_images/image_1580.png
#  extracting: /tmp/test_images/image_1576.png
#  extracting: /tmp/test_images/image_1594.png
#  extracting: /tmp/test_images/image_1558.png
#  extracting: /tmp/test_images/image_1584.png
#  extracting: /tmp/test_images/image_1571.png
#  extracting: /tmp/test_images/image_1560.png
#  extracting: /tmp/test_images/image_1588.png
#  extracting: /tmp/test_images/image_1599.png
#  extracting: /tmp/test_images/image_1595.png
#  extracting: /tmp/test_images/image_1555.png
#  extracting: /tmp/test_images/image_1597.png
#  extracting: /tmp/test_images/image_1567.png
#  extracting: /tmp/test_images/image_1549.png
#  extracting: /tmp/test_images/image_1589.png
#  extracting: /tmp/test_images/image_1570.png
#  extracting: /tmp/test_images/image_1593.png
#  extracting: /tmp/test_images/image_1556.png
#  extracting: /tmp/test_images/image_1553.png
#  extracting: /tmp/test_images/image_1557.png
#  extracting: /tmp/test_images/image_1586.png
#  extracting: /tmp/test_images/image_1569.png
#  extracting: /tmp/test_images/image_1585.png
#  extracting: /tmp/test_images/image_1563.png
#  extracting: /tmp/test_images/image_1561.png
#  extracting: /tmp/test_images/image_1554.png
#  extracting: /tmp/test_images/image_1552.png
#  extracting: /tmp/test_images/image_1551.png
#  extracting: /tmp/test_images/image_1596.png
#  extracting: /tmp/test_images/image_1564.png
#  extracting: /tmp/test_images/image_1562.png
#  extracting: /tmp/test_images/image_1565.png
#  extracting: /tmp/test_images/image_1581.png
#  extracting: /tmp/test_images/image_1550.png
#  extracting: /tmp/test_images/image_1592.png
#  extracting: /tmp/test_images/image_1574.png
#  extracting: /tmp/test_images/image_0051.png
#  extracting: /tmp/test_images/image_0018.png
#  extracting: /tmp/test_images/image_0043.png
#  extracting: /tmp/test_images/image_0075.png
#  extracting: /tmp/test_images/image_0037.png
#  extracting: /tmp/test_images/image_0031.png
#  extracting: /tmp/test_images/image_0059.png
#  extracting: /tmp/test_images/image_0049.png
#  extracting: /tmp/test_images/image_0002.png
#  extracting: /tmp/test_images/image_0020.png
#  extracting: /tmp/test_images/image_0017.png
#  extracting: /tmp/test_images/image_0044.png
#  extracting: /tmp/test_images/image_0007.png
#  extracting: /tmp/test_images/image_0065.png
#  extracting: /tmp/test_images/image_0048.png
#  extracting: /tmp/test_images/image_0012.png
#  extracting: /tmp/test_images/image_0003.png
#  extracting: /tmp/test_images/image_0019.png
#  extracting: /tmp/test_images/image_0069.png
#  extracting: /tmp/test_images/image_0023.png
#  extracting: /tmp/test_images/image_0021.png
#  extracting: /tmp/test_images/image_0042.png
#  extracting: /tmp/test_images/image_0064.png
#  extracting: /tmp/test_images/image_0046.png
#  extracting: /tmp/test_images/image_0038.png
# ...
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0459.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0460.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0466.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0433.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0569.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0535.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0532.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0575.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0501.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0523.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0562.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0555.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0519.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0541.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0556.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0534.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0580.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0515.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0533.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0529.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0514.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0563.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0571.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0554.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0510.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0509.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0516.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0573.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0543.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0508.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0559.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0530.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0528.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0538.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0561.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0504.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0577.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0576.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0578.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0542.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0565.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0521.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0560.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0570.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0568.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0537.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0525.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0567.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0566.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0502.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0526.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0548.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0503.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0564.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0522.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0552.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0507.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0505.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0550.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0506.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0545.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0512.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0513.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0579.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0547.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0511.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0524.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0500.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0553.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0499.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0558.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0518.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0539.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0520.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0540.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0517.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0546.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0549.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0527.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0551.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0531.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0536.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0574.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0544.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0557.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0572.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0620.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0647.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0619.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0600.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0657.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0607.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0659.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0630.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0641.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0650.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0654.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0612.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0603.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0637.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0586.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0628.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0598.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0652.png
#  extracting: /tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0629.png

# %%
train_images_path = '/tmp/train_images'
train_labels_path = '/tmp/train_labels'
val_images_path = '/tmp/val_images'
val_labels_path = '/tmp/val_labels'

# %%
# !pip install opencv-python torch torchvision
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/61.8 MB ? eta -:--:--
#      ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/61.8 MB 68.7 MB/s eta 0:00:01
#      ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/61.8 MB 150.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/61.8 MB 192.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 31.5/61.8 MB 182.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 38.8/61.8 MB 224.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━ 48.5/61.8 MB 136.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 55.3/61.8 MB 174.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 61.8/61.8 MB 201.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 61.8/61.8 MB 201.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 61.8/61.8 MB 201.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 61.8/61.8 MB 201.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /opt/conda/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.9/site-packages (0.15.2)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from opencv-python) (1.23.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch) (4.4.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from torch) (2.8.7)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.9/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.9/site-packages (from torch) (11.7.101)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/557.1 MB 207.2 MB/s eta 0:00:03
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/557.1 MB 198.8 MB/s eta 0:00:03
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/557.1 MB 168.4 MB/s eta 0:00:04
#      ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/557.1 MB 170.2 MB/s eta 0:00:04
#      ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/557.1 MB 170.8 MB/s eta 0:00:04
#      ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/557.1 MB 156.9 MB/s eta 0:00:04
#      ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/557.1 MB 135.9 MB/s eta 0:00:04
#      ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/557.1 MB 170.5 MB/s eta 0:00:03
#      ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.8/557.1 MB 229.1 MB/s eta 0:00:03
#      ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/557.1 MB 175.1 MB/s eta 0:00:03
#      ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/557.1 MB 89.2 MB/s eta 0:00:06
#      ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/557.1 MB 81.5 MB/s eta 0:00:06
#      ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/557.1 MB 189.9 MB/s eta 0:00:03
#      ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/557.1 MB 156.5 MB/s eta 0:00:03
#      ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/557.1 MB 180.4 MB/s eta 0:00:03
#      ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/557.1 MB 189.7 MB/s eta 0:00:03
#      ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/557.1 MB 141.4 MB/s eta 0:00:04
#      ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/557.1 MB 133.0 MB/s eta 0:00:04
#      ━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/557.1 MB 188.4 MB/s eta 0:00:03
#      ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/557.1 MB 206.9 MB/s eta 0:00:02
#      ━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/557.1 MB 191.0 MB/s eta 0:00:03
#      ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━ 175.6/557.1 MB 157.1 MB/s eta 0:00:03
#      ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 181.0/557.1 MB 156.2 MB/s eta 0:00:03
#      ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━ 190.8/557.1 MB 143.1 MB/s eta 0:00:03
#      ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 196.2/557.1 MB 133.7 MB/s eta 0:00:03
#      ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 202.1/557.1 MB 159.8 MB/s eta 0:00:03
#      ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━ 214.3/557.1 MB 165.1 MB/s eta 0:00:03
#      ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━ 222.3/557.1 MB 218.0 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 234.3/557.1 MB 178.3 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 240.6/557.1 MB 176.6 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━ 248.5/557.1 MB 130.3 MB/s eta 0:00:03
#      ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━ 252.7/557.1 MB 126.5 MB/s eta 0:00:03
#      ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 264.9/557.1 MB 172.3 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 271.5/557.1 MB 182.6 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 277.9/557.1 MB 183.9 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━ 287.9/557.1 MB 137.8 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 295.1/557.1 MB 157.8 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 309.6/557.1 MB 211.8 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 311.6/557.1 MB 139.3 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 315.6/557.1 MB 96.4 MB/s eta 0:00:03
#      ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 318.8/557.1 MB 72.7 MB/s eta 0:00:04
#      ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 322.9/557.1 MB 76.7 MB/s eta 0:00:04
#      ━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 334.1/557.1 MB 166.3 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 339.7/557.1 MB 168.1 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 353.1/557.1 MB 195.4 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 359.7/557.1 MB 203.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 371.6/557.1 MB 165.8 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 377.4/557.1 MB 174.9 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 382.7/557.1 MB 165.5 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 396.4/557.1 MB 213.6 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 400.9/557.1 MB 166.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 414.6/557.1 MB 215.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 419.3/557.1 MB 167.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━ 429.5/557.1 MB 148.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━ 434.7/557.1 MB 152.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 444.6/557.1 MB 165.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 448.5/557.1 MB 123.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 455.7/557.1 MB 203.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 467.3/557.1 MB 161.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 472.2/557.1 MB 154.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 484.0/557.1 MB 170.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 492.0/557.1 MB 220.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 497.5/557.1 MB 182.6 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━ 511.3/557.1 MB 205.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 516.4/557.1 MB 165.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━ 528.8/557.1 MB 181.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━ 534.5/557.1 MB 171.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 548.7/557.1 MB 196.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 554.7/557.1 MB 176.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 557.1/557.1 MB 173.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.9/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.9/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.9/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.9/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.9/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.9/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.9/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.9/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.4.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.9/site-packages (from triton==2.0.0->torch) (3.26.3)
# Requirement already satisfied: lit in /opt/conda/lib/python3.9/site-packages (from triton==2.0.0->torch) (16.0.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.9/site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->torchvision) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->torch) (1.2.1)
# Installing collected packages: opencv-python, nvidia-cudnn-cu11
#   Attempting uninstall: nvidia-cudnn-cu11
#     Found existing installation: nvidia-cudnn-cu11 8.6.0.163
#     Uninstalling nvidia-cudnn-cu11-8.6.0.163:
#       Successfully uninstalled nvidia-cudnn-cu11-8.6.0.163
# Successfully installed nvidia-cudnn-cu11-8.5.0.96 opencv-python-4.7.0.72

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import os

train_crops_path = "/tmp/train_crops"
num_plushies = 200
os.mkdir(train_crops_path)

for i in range(num_plushies):
    os.mkdir(os.path.join(train_crops_path, str(i)))

# %%
val_crops_path = "/tmp/val_crops"
num_plushies = 10
os.mkdir(val_crops_path)

for i in range(num_plushies):
    os.mkdir(os.path.join(val_crops_path, str(i)))

# %%
import cv2
import numpy as np
import pandas as pd
import os

images_path = train_images_path
labels_path = train_labels_path
annotated_images_path = train_crops_path


for label_name in os.listdir(labels_path):
    if label_name[-4:] != ".txt":
        continue
    image_name = label_name[:-4] + ".png"
#     print("Checking", image_name)

    image_path = os.path.join(images_path, image_name)
    label_path = os.path.join(labels_path, label_name)

    df = pd.read_csv(label_path, delim_whitespace=True, header=None)
    df.columns = ["cat", "xc", "yc", "w", "h"]

    img = cv2.imread(image_path)
    img_h, img_w = img.shape[:2]

    for i in range(df.shape[0]):
        bb = df.iloc[i]
        cat = str(int(bb["cat"]))
        tl = (int((bb["xc"] - bb["w"]/2) * img_w), int((bb["yc"] - bb["h"]/2) * img_h))
        br = (int((bb["xc"] + bb["w"]/2) * img_w), int((bb["yc"] + bb["h"]/2) * img_h))

        cropped_img = img[tl[1]:br[1], tl[0]:br[0]]
        annotated_img_name = f"{cat}_{len(os.listdir(os.path.join(annotated_images_path, cat)))}.png"
        cv2.imwrite(os.path.join(annotated_images_path, cat, annotated_img_name), cropped_img)

# %%
import cv2
import numpy as np
import pandas as pd
import os

images_path = val_images_path
labels_path = val_labels_path
annotated_images_path = val_crops_path


for label_name in os.listdir(labels_path):
    if label_name[-4:] != ".txt":
        continue
    image_name = label_name[:-4] + ".png"
#     print("Checking", image_name)

    image_path = os.path.join(images_path, image_name)
    label_path = os.path.join(labels_path, label_name)

    df = pd.read_csv(label_path, delim_whitespace=True, header=None)
    df.columns = ["cat", "xc", "yc", "w", "h"]

    img = cv2.imread(image_path)
    img_h, img_w = img.shape[:2]

    for i in range(df.shape[0]):
        bb = df.iloc[i]
        cat = str(int(bb["cat"]))
        tl = (int((bb["xc"] - bb["w"]/2) * img_w), int((bb["yc"] - bb["h"]/2) * img_h))
        br = (int((bb["xc"] + bb["w"]/2) * img_w), int((bb["yc"] + bb["h"]/2) * img_h))

        cropped_img = img[tl[1]:br[1], tl[0]:br[0]]
        annotated_img_name = f"{cat}_{len(os.listdir(os.path.join(annotated_images_path, cat)))}.png"
        cv2.imwrite(os.path.join(annotated_images_path, cat, annotated_img_name), cropped_img)

# %%
image = cv2.imread(f'{train_crops_path}/0/0_21.png')
plt.imshow(image)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import os
import random

counts = {}

crops_path = train_crops_path
num_plushies = 200

for i in range(num_plushies):
    counts[i] = len(os.listdir(os.path.join(crops_path, str(i))))
print(counts)

lines = []

def add_match(plushie, num1, num2):
    line = f"{plushie} {num1} {num2}\n"
    lines.append(line)

def add_mismatch(plushie1, num1, plushie2, num2):
    line = f"{plushie1} {num1} {plushie2} {num2}\n"
    lines.append(line)

len_data = 4000

for i in range(len_data):
#     print(i)
    plushie = random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])

    while not (os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num2}.png")):
        print(num1, num2, plushie)
        num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])
    
    add_match(plushie, num1, num2)

for i in range(len_data):
#     print(i)
    plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))
    while plushie1 == plushie2:
        plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])
                              
                              
    while not (os.path.exists(f"{crops_path}/{plushie1}/{plushie1}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie2}/{plushie2}_{num2}.png")):
        num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])

    add_mismatch(plushie1, num1, plushie2, num2)


f = open("/tmp/plushie_pairs_train.txt", "a")
f.writelines(lines)
f.close()
# Out:
# {0: 67, 1: 65, 2: 66, 3: 65, 4: 65, 5: 65, 6: 61, 7: 66, 8: 66, 9: 64, 10: 66, 11: 65, 12: 65, 13: 64, 14: 66, 15: 65, 16: 66, 17: 65, 18: 66, 19: 65, 20: 65, 21: 66, 22: 65, 23: 66, 24: 65, 25: 65, 26: 65, 27: 65, 28: 64, 29: 65, 30: 65, 31: 65, 32: 65, 33: 66, 34: 66, 35: 65, 36: 65, 37: 65, 38: 65, 39: 65, 40: 65, 41: 64, 42: 65, 43: 65, 44: 66, 45: 65, 46: 66, 47: 63, 48: 66, 49: 65, 50: 65, 51: 65, 52: 64, 53: 66, 54: 65, 55: 66, 56: 66, 57: 65, 58: 65, 59: 65, 60: 65, 61: 63, 62: 65, 63: 64, 64: 65, 65: 65, 66: 66, 67: 66, 68: 65, 69: 65, 70: 66, 71: 66, 72: 66, 73: 65, 74: 63, 75: 64, 76: 65, 77: 65, 78: 65, 79: 63, 80: 63, 81: 64, 82: 64, 83: 63, 84: 64, 85: 64, 86: 64, 87: 56, 88: 56, 89: 56, 90: 58, 91: 62, 92: 62, 93: 58, 94: 65, 95: 63, 96: 57, 97: 61, 98: 61, 99: 56, 100: 60, 101: 56, 102: 61, 103: 60, 104: 57, 105: 61, 106: 60, 107: 54, 108: 57, 109: 59, 110: 60, 111: 56, 112: 57, 113: 60, 114: 55, 115: 56, 116: 56, 117: 61, 118: 57, 119: 57, 120: 57, 121: 56, 122: 56, 123: 55, 124: 59, 125: 59, 126: 59, 127: 56, 128: 60, 129: 67, 130: 58, 131: 62, 132: 59, 133: 58, 134: 56, 135: 58, 136: 59, 137: 64, 138: 58, 139: 57, 140: 56, 141: 59, 142: 57, 143: 62, 144: 60, 145: 60, 146: 60, 147: 61, 148: 63, 149: 61, 150: 60, 151: 59, 152: 59, 153: 60, 154: 61, 155: 59, 156: 56, 157: 57, 158: 61, 159: 59, 160: 60, 161: 59, 162: 63, 163: 59, 164: 54, 165: 59, 166: 62, 167: 57, 168: 58, 169: 59, 170: 59, 171: 61, 172: 60, 173: 56, 174: 58, 175: 61, 176: 61, 177: 60, 178: 62, 179: 59, 180: 60, 181: 58, 182: 58, 183: 58, 184: 59, 185: 59, 186: 60, 187: 59, 188: 59, 189: 59, 190: 61, 191: 61, 192: 59, 193: 59, 194: 61, 195: 57, 196: 63, 197: 62, 198: 59, 199: 58}

# %%
import os
import random

counts = {}

crops_path = val_crops_path
num_plushies = 10

for i in range(num_plushies):
    counts[i] = len(os.listdir(os.path.join(crops_path, str(i))))
print(counts)

lines = []

def add_match(plushie, num1, num2):
    line = f"{plushie} {num1} {num2}\n"
    lines.append(line)

def add_mismatch(plushie1, num1, plushie2, num2):
    line = f"{plushie1} {num1} {plushie2} {num2}\n"
    lines.append(line)

len_data = 400

for i in range(len_data):
#     print(i)
    plushie = random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])

    while not (os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num2}.png")):
        print(num1, num2, plushie)
        num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])
    
    add_match(plushie, num1, num2)

for i in range(len_data):
#     print(i)
    plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))
    while plushie1 == plushie2:
        plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])
                              
                              
    while not (os.path.exists(f"{crops_path}/{plushie1}/{plushie1}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie2}/{plushie2}_{num2}.png")):
        num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])

    add_mismatch(plushie1, num1, plushie2, num2)


f = open("/tmp/plushie_pairs_val.txt", "a")
f.writelines(lines)
f.close()
# Out:
# {0: 179, 1: 177, 2: 169, 3: 163, 4: 163, 5: 163, 6: 166, 7: 169, 8: 173, 9: 177}

# %%
import torch
import matplotlib.pyplot as plt

def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
    
def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

def show_img(img1, img2):
    axs = plt.figure(figsize=(9, 9)).subplots(1, 2)
    axs[0].imshow(img1)
    axs[1].imshow(img2)


def accuracy(preds, labels):
    preds = torch.flatten(preds)
    preds[preds > 0] = 1
    preds[preds < 0] = 0
    return torch.sum(preds == labels).item() / len(labels)


class DeviceDataLoader():
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
    
    def __iter__(self):
        for batch in self.dl:
            yield to_device(batch, self.device)
    
    def __len__(self):
        return len(self.dl)

# %%
import torchvision.transforms as tt
import cv2

class BGR2RGB:
    def __call__(self, image):
        return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

class SquarePad:
    def __call__(self, image):
        max_wh = max(image.shape[:2])
        p_left, p_top = [(max_wh - s) // 2 for s in image.shape[:2]]
        p_right, p_bottom = [max_wh - (s+pad) for s, pad in zip(image.shape[:2], [p_left, p_top])]
        return cv2.copyMakeBorder(image, p_top, p_bottom, p_left, p_right, cv2.BORDER_CONSTANT, None, value = 0)


class Resize():
    def __init__(self, output_size=(128, 128)):
        assert isinstance(output_size, (tuple))
        self.output_size = output_size

    def __call__(self, image):
        return cv2.resize(image, self.output_size, interpolation = cv2.INTER_LINEAR)

class Transforms:
    def __init__(self):
        self.transform = tt.Compose([BGR2RGB(), 
                        SquarePad(),
                        Resize((128, 128)),
                        tt.ToTensor(),
                        tt.Normalize(0, 0.5)])

    def __call__(self, image):
        return self.transform(image)

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torch import cat
import torch.nn as nn

class SiameseNetwork(nn.Module):
    """
        https://github.com/pytorch/examples/tree/main/siamese_network

        BCE Loss
    """
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.resnet = resnet50(ResNet50_Weights.DEFAULT)

        for ct, child in enumerate(self.resnet.children()):
            if ct < 6:
                for param in child.parameters():
                    param.requires_grad = False


        self.fc_in_features = self.resnet.fc.in_features
        
        # remove the last layer of resnet18 (linear layer which is before avgpool layer)
        self.resnet = nn.Sequential(*(list(self.resnet.children())[:-1]))

        # add linear layers to compare between the features of the two images
        self.fc = nn.Sequential(
            nn.Linear(self.fc_in_features * 2, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 1),
        )


    def get_embeddings(self, x):
        output = self.resnet(x)
        output = output.view(output.size()[0], -1)
        return output

    def forward(self, input1, input2):
        output1 = self.get_embeddings(input1)
        output2 = self.get_embeddings(input2)
        output = cat((output1, output2), 1)
        output = self.fc(output)
        
        return output

# %%
import os
import matplotlib.pyplot as plt

from PIL import Image
import cv2

from torch.utils.data import Dataset




class PlushieTrainDataset(Dataset):
    
    def __init__(self, filepath, img_dir, transform=None):
        self.samples = []
        self.img_dir = img_dir
        self.transform = transform

        with open(filepath, 'r') as f:
            self.samples = [line.strip() for line in f]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, i):
        line = self.samples[i].split()
        if len(line) == 3:
            anchor_name, anchor_num, img_num = line
            img_name = anchor_name
            is_same = 1
        elif len(line) == 4:
            anchor_name, anchor_num, img_name, img_num = line
            is_same = 0
        else:
            print(len(line), line)
            raise Exception("Shouldn't be here")
        
        anchor = cv2.imread(os.path.join(self.img_dir, str(anchor_name), f"{anchor_name}_{anchor_num}.png"))
        img = cv2.imread(os.path.join(self.img_dir, img_name, f"{img_name}_{img_num}.png"))
        
        if self.transform:
            anchor = self.transform(anchor)
            img = self.transform(img)

        return anchor, img, is_same

# %%
import numpy as np
import torch



def loss_batch(model, loss_func, anchor, image, label, opt=None, metric=None): # Update model weights and return metrics given xb, yb, model
    preds = model(anchor, image)
    loss = loss_func(preds, label.unsqueeze(1).float())
    
    if opt is not None:
        loss.backward()
        opt.step()
        opt.zero_grad()
        
    metric_result = None
    if metric is not None:
        metric_result = metric(preds, label)
        
    return loss.item(), len(anchor), metric_result


def fit(epochs, model, loss_func, train_dl, val_dl, opt_func=torch.optim.SGD, lr=0.01, metric=None):
    train_losses, val_losses, val_metrics = [] , [], []
    
    opt = opt_func(model.parameters(), lr=lr)
    
    for epoch in range(1, epochs+1):
        model.train() # Setting for pytorch - training mode
        for anchor,image,label in train_dl:
            train_loss, _, _ = loss_batch(model, loss_func, anchor, image, label, opt) # update weights
            
        model.eval() # Setting - eval mode
        val_loss, total, val_metric = evaluate(model, loss_func, val_dl, metric)
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_metrics.append(val_metric)
        
        if metric is None:
            print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}".format(
            epoch, train_loss, val_loss))
        else:
            print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_{}: {:.4f}".format(
            epoch, train_loss, val_loss, metric.__name__, val_metric))
            
    return train_losses, val_losses, val_metrics


def evaluate(model, loss_func, val_dl, metric=None):
    with torch.no_grad():
        results = [loss_batch(model, loss_func, anchor, image, label, metric=metric) for anchor, image, label in val_dl]
        
        losses, nums, metrics = zip(*results)
        total = np.sum(nums)
        
        avg_loss = np.sum(np.multiply(losses, nums)) / total
        
        avg_metric = None
        if metric is not None:
            avg_metric = np.sum(np.multiply(metrics, nums)) / total
            
        return avg_loss, total, avg_metric



train_filepath = "/tmp/plushie_pairs_train.txt"
train_img_dir = train_crops_path
val_filepath = "/tmp/plushie_pairs_val.txt"
val_img_dir = val_crops_path
train_bs = 8
test_bs = 4
num_epochs = 1
lr = 0.005

torch.autograd.set_detect_anomaly(True)

transform = Transforms()
train_dataset = PlushieTrainDataset(filepath=train_filepath, img_dir=train_img_dir, transform=transform)
valid_dataset = PlushieTrainDataset(filepath=val_filepath, img_dir=val_img_dir, transform=transform)
network = SiameseNetwork()


print("The length of Train set is {}".format(len(train_dataset)))
print("The length of Valid set is {}".format(len(valid_dataset)))

train_dl = torch.utils.data.DataLoader(train_dataset, batch_size=train_bs, shuffle=True, num_workers=4)
val_dl = torch.utils.data.DataLoader(valid_dataset, batch_size=test_bs, shuffle=True, num_workers=4)

device = get_default_device()
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
to_device(network, device)

criterion = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam


train_losses, val_losses, val_metrics = fit(num_epochs, network, criterion, 
                                        train_dl, val_dl, optimizer, lr, accuracy)

torch.save(network.state_dict(), '/tmp/model2.pth')
# Out:
# The length of Train set is 8000
# The length of Valid set is 800
# Epoch [1], train_loss: 0.7087, val_loss: 0.6934, val_accuracy: 0.4988

# %%
def predict_image(model, target, img, transform=None, device=torch.device('cpu')):
    xb, xb2 = transform(target).unsqueeze(0), transform(img).unsqueeze(0) # Convert to batch of 1
    model.eval()
    yb = model(xb.to(device), xb2.to(device))
    return yb

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 5)) (3.1.31)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 7)) (1.23.3)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 8)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 9)) (9.2.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 12)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 13)) (1.10.1)
# Collecting thop>=0.1.1 (from -r ../requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.7.0 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: torchvision>=0.8.1 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 16)) (0.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 17)) (4.64.1)
# Collecting ultralytics>=8.0.100 (from -r ../requirements.txt (line 18))
#   Downloading ultralytics-8.0.110-py3-none-any.whl (592 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/592.7 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 592.7/592.7 kB 37.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 27)) (1.5.0)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.9/site-packages (from -r ../requirements.txt (line 28)) (0.12.0)
# Collecting setuptools>=65.5.1 (from -r ../requirements.txt (line 42))
#   Using cached setuptools-67.8.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.9/site-packages (from gitpython>=3.1.30->-r ../requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3->-r ../requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3->-r ../requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3->-r ../requirements.txt (line 6)) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3->-r ../requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3->-r ../requirements.txt (line 6)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3->-r ../requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.3->-r ../requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.9/site-packages (from requests>=2.23.0->-r ../requirements.txt (line 12)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.23.0->-r ../requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.23.0->-r ../requirements.txt (line 12)) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.23.0->-r ../requirements.txt (line 12)) (2023.5.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (3.12.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (4.4.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (2.8.7)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.9/site-packages (from torch>=1.7.0->-r ../requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->-r ../requirements.txt (line 15)) (0.37.1)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.7.0->-r ../requirements.txt (line 15)) (3.26.3)
# Requirement already satisfied: lit in /opt/conda/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.7.0->-r ../requirements.txt (line 15)) (16.0.5)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.1.4->-r ../requirements.txt (line 27)) (2022.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r ../requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r ../requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch>=1.7.0->-r ../requirements.txt (line 15)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->torch>=1.7.0->-r ../requirements.txt (line 15)) (1.2.1)
# Installing collected packages: setuptools, ultralytics, thop
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.4.1
#     Uninstalling setuptools-65.4.1:
#       Successfully uninstalled setuptools-65.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dagster 1.0.15 requires grpcio<1.48.1,>=1.32.0, but you have grpcio 1.54.2 which is incompatible.
# noteable 2.0.0 requires ipython[kernel]<9.0.0,>=8.10.0, but you have ipython 8.0.1 which is incompatible.
# noteable 2.0.0 requires pandas<2.0.0,>=1.5.3, but you have pandas 1.5.0 which is incompatible.
# noteable 2.0.0 requires tqdm<5.0.0,>=4.65.0, but you have tqdm 4.64.1 which is incompatible.
# Successfully installed setuptools-67.8.0 thop-0.1.1.post2209072238 ultralytics-8.0.110

# %%
bb_ann = {"Image_ID": [], "class": [], "confidence": [], "ymin": [], "xmin": [], 
          "ymax": [], "xmax": []}


yolo_repo_path = '..'
yolo_model_path = '../best.pt'
reid_model_path = "model.pth"

yolo_model = torch.hub.load(yolo_repo_path, 'custom', path=yolo_model_path, source='local')

reid_model = SiameseNetwork()
reid_model.load_state_dict(torch.load(reid_model_path, map_location=torch.device('cuda')))

test_dir = "/tmp/test_images"
suspect_dir = "/tmp/suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops"

reid_transforms = Transforms()

def detect_objects(image_name):
    image_path = os.path.join(test_dir, image_name)
    suspect_path = os.path.join(suspect_dir, image_name)

    img = cv2.imread(image_path)
    suspect = cv2.imread(suspect_path)
    
    img_h, img_w = img.shape[:2]

    # Perform object detection
    results = yolo_model(img)

    # Print the detected objects with their classes, confidence scores, and bounding box coordinates
    for result in results.xyxy[0].tolist():
        class_id = int(result[5])
        confidence = result[4]
        x1, y1, x2, y2 = result[:4]
        plushie = img[int(y1):int(y2), int(x1):int(x2)]
        match_confidence = float(predict_image(reid_model, suspect, plushie, transform=reid_transforms))
        plushie_class = 1 if match_confidence > 0 else 0

        bb_ann["Image_ID"].append(image_name[:-4])
        bb_ann["class"].append(plushie_class) 
        bb_ann["confidence"].append(confidence)
        bb_ann["ymin"].append(y1 / img_h)
        bb_ann["xmin"].append(x1 / img_w)
        bb_ann["ymax"].append(y2 / img_h)
        bb_ann["xmax"].append(x2 / img_w)
        
    if not results.xyxy[0].tolist():
        bb_ann["Image_ID"].append(image_name[:-4])
        bb_ann["class"].append(0) 
        bb_ann["confidence"].append(0)
        bb_ann["ymin"].append(0)
        bb_ann["xmin"].append(0)
        bb_ann["ymax"].append(0)
        bb_ann["xmax"].append(0)



for i, image_name in enumerate(os.listdir(test_dir)[:10]):
    detect_objects(image_name)
    if i % 10 == 0:
        print(i)


df = pd.DataFrame.from_dict(bb_ann)
# df.to_csv("../../datasets/reid_results/results.csv", index=False)
df.to_csv("/tmp/results.csv", index=False)
# Out:
# fatal: detected dubious ownership in repository at '/etc/noteable/project'
# To add an exception for this directory, call:
#
# 	git config --global --add safe.directory /etc/noteable/project
# YOLOv5 🚀 2023-5-29 Python-3.9.13 torch-2.0.1+cu117 CUDA:0 (Tesla T4, 15110MiB)
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# 0

# %%
df.head(10)

# %%
print("hello")
# Out:
# hello

# %%
# %ntbl push datasets "reid_results/results.csv"
# Out:
# Dataset files are being pushed to remote storage
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #008000; text-decoration-color: #008000">Dataset files pushed to remote storage</span>
# </pre>

# %%
# %ntbl pull datasets "reid_results/results.csv"
# Out:
# Dataset files are being pulled (this may take awhile)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #008000; text-decoration-color: #008000">Dataset files pulled from remote storage</span>
# </pre>

# %%
# !pwd

# %%
# !cp "/tmp/results.csv" ..

# %%
# !ls -la
# Out:
# total 96272
# drwxr-sr-x  2 noteable noteable       89 May 28 15:13 .
# drwxrwsrwx 12 root     noteable     4096 May 28 15:12 ..
# -rw-r--r--  1 noteable noteable    40778 May 28 15:13 cv_challenge.ipynb
# -rw-r--r--  1 noteable noteable 98529525 May 28 14:12 model.pth
# -rw-r--r--  1 noteable noteable        0 May 28 15:13 .noteablekeep
# -rw-r--r--  1 noteable noteable     2611 May 28 14:12 results.csv

# %%
# !pwd
# Out:
# /etc/noteable/project/ReID
