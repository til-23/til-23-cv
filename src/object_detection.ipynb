# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# Receiving objects:   0% (1/15705)
# Receiving objects:  20% (3141/15705)
# Receiving objects:  28% (4398/15705)
# Receiving objects:  37% (5811/15705)
# Receiving objects:  52% (8167/15705)
# Receiving objects:  60% (9423/15705)
# Receiving objects:  69% (10837/15705)
# Receiving objects:  95% (14920/15705)
# remote: Total 15705 (delta 9), reused 15 (delta 3), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.51 MiB | 38.89 MiB/s, done.
# Resolving deltas:  17% (1828/10750)
# Resolving deltas:  36% (3870/10750)
# Resolving deltas:  55% (5913/10750)
# Resolving deltas:  79% (8493/10750)
# Resolving deltas: 100% (10750/10750), done.

# %%
# !ls
# Out:
#  classes.names	   'My First Notebook.ipynb'	 reannotate.py
#  custom.yaml	    object_detection.ipynb	 yolov5
#  generate_path.py   object_detection_mel.ipynb	 yolov5s.pt

# %%
# %ntbl pull datasets "BrainHack TIL-23 OD _ ReID Novice"
# Out:
# Dataset files are being pulled (this may take awhile)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #008000; text-decoration-color: #008000">Dataset files pulled from remote storage</span>
# </pre>

# %%
# !unzip "../datasets/BrainHack TIL-23 OD _ ReID Novice/Train.zip" -d "/tmp/train_images"

# !unzip "../datasets/BrainHack TIL-23 OD _ ReID Novice/train_labels.zip" -d "/tmp/train_labels"

# !unzip "../datasets/BrainHack TIL-23 OD _ ReID Novice/Validation.zip" -d "/tmp/val_images"

# !unzip "../datasets/BrainHack TIL-23 OD _ ReID Novice/val_labels.zip" -d "/tmp/val_labels"
# Out:
# Archive:  ../datasets/BrainHack TIL-23 OD _ ReID Novice/Train.zip
#  extracting: /tmp/train_images/image_4655.png
#  extracting: /tmp/train_images/image_4676.png
#  extracting: /tmp/train_images/image_4654.png
#  extracting: /tmp/train_images/image_4667.png
#  extracting: /tmp/train_images/image_4660.png
#  extracting: /tmp/train_images/image_4680.png
#  extracting: /tmp/train_images/image_4673.png
#  extracting: /tmp/train_images/image_4674.png
#  extracting: /tmp/train_images/image_4670.png
#  extracting: /tmp/train_images/image_4661.png
#  extracting: /tmp/train_images/image_4671.png
#  extracting: /tmp/train_images/image_4664.png
#  extracting: /tmp/train_images/image_4685.png
#  extracting: /tmp/train_images/image_4666.png
#  extracting: /tmp/train_images/image_4659.png
#  extracting: /tmp/train_images/image_4663.png
#  extracting: /tmp/train_images/image_4656.png
#  extracting: /tmp/train_images/image_4675.png
#  extracting: /tmp/train_images/image_4684.png
# ...

# %%
# !ls yolov5
# Out:
# benchmarks.py	 data	     LICENSE	      requirements.txt	tutorial.ipynb
# CITATION.cff	 detect.py   models	      segment		utils
# classify	 export.py   README.md	      setup.cfg		val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %%
# !mkdir yolov5/custom_dataset

# %%
# !mkdir yolov5/custom_dataset/images

# %%
# !mkdir yolov5/custom_dataset/images/train
# !mkdir yolov5/custom_dataset/images/val

# %%
# !ls yolov5/custom_dataset/images
# Out:
# train  val

# %%
# !mkdir yolov5/custom_dataset/labels
# !mkdir yolov5/custom_dataset/labels/train
# !mkdir yolov5/custom_dataset/labels/val

# %%
# !cp reannotate.py yolov5/custom_dataset
# !cp generate_path.py yolov5/custom_dataset
# !cp classes.names yolov5/custom_dataset

# %%
# !cp custom.yaml yolov5/data

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/61.8 MB ? eta -:--:--
#      ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/61.8 MB 77.0 MB/s eta 0:00:01
#      ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/61.8 MB 157.2 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/61.8 MB 142.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 24.1/61.8 MB 111.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━ 28.7/61.8 MB 116.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 36.7/61.8 MB 123.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━ 41.7/61.8 MB 132.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 53.5/61.8 MB 175.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 55.6/61.8 MB 163.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 60.8/61.8 MB 114.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 61.8/61.8 MB 115.3 MB/s eta 0:00:01
# ...

# %%
# !pip install pandas==1.5.3
# !pip install tqdm==4.65
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/12.2 MB ? eta -:--:--
#      ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/12.2 MB 39.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/12.2 MB 69.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 11.9/12.2 MB 100.4 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 12.2/12.2 MB 97.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 12.2/12.2 MB 97.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 12.2/12.2 MB 97.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 12.2/12.2 MB 97.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 30.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.0
#     Uninstalling pandas-1.5.0:
#       Successfully uninstalled pandas-1.5.0
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# adagio                        0.2.4
# aiofiles                      22.1.0
# aiosqlite                     0.19.0
# alembic                       1.11.1
# altair                        4.2.0
# ansiwrap                      0.8.4
# antlr4-python3-runtime        4.11.1
# anyio                         3.6.1
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asn1crypto                    1.5.1
# asttokens                     2.0.8
# astunparse                    1.6.3
# async-generator               1.10
# attrs                         22.1.0
# Babel                         2.10.3
# backcall                      0.2.0
# backoff                       2.2.1
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.1
# ...

# %%
# !cp -r /tmp/train_labels/. yolov5/custom_dataset/labels/train

# %%
# !cp -r /tmp/train_images/. yolov5/custom_dataset/images/train

# %%
# !cp -r /tmp/val_images/. yolov5/custom_dataset/images/val

# %%
# !cp -r /tmp/val_labels/. yolov5/custom_dataset/labels/val

# %%
# !ls yolov5/custom_dataset/labels/train
# Out:
# image_0000.txt	image_1133.txt	image_2266.txt	image_3399.txt	image_4532.txt
# image_0001.txt	image_1134.txt	image_2267.txt	image_3400.txt	image_4533.txt
# image_0002.txt	image_1135.txt	image_2268.txt	image_3401.txt	image_4534.txt
# image_0003.txt	image_1136.txt	image_2269.txt	image_3402.txt	image_4535.txt
# image_0004.txt	image_1137.txt	image_2270.txt	image_3403.txt	image_4536.txt
# image_0005.txt	image_1138.txt	image_2271.txt	image_3404.txt	image_4537.txt
# image_0006.txt	image_1139.txt	image_2272.txt	image_3405.txt	image_4538.txt
# image_0007.txt	image_1140.txt	image_2273.txt	image_3406.txt	image_4539.txt
# image_0008.txt	image_1141.txt	image_2274.txt	image_3407.txt	image_4540.txt
# image_0009.txt	image_1142.txt	image_2275.txt	image_3408.txt	image_4541.txt
# image_0010.txt	image_1143.txt	image_2276.txt	image_3409.txt	image_4542.txt
# image_0011.txt	image_1144.txt	image_2277.txt	image_3410.txt	image_4543.txt
# ...

# %%
# !python3 reannotate.py
# Out:
# /etc/noteable/project/yolov5/custom_dataset/labels/val/.noteablekeep
# /etc/noteable/project/yolov5/custom_dataset/labels/val/image_0000.txt
# ['0', '0.08016566657742966', '0.6518675703938716', '0.13887016521022694', '0.22731556558368438\n']
# ['1', '0.30986576973822477', '0.6840537125350188', '0.07954158402965454', '0.18207647517487363\n']
# ['2', '0.5148032983727551', '0.7343331464519938', '0.1314237503107072', '0.20257024949377112\n']
# /etc/noteable/project/yolov5/custom_dataset/labels/val/image_0020.txt
# ['0', '0.8301748917538202', '0.7706050371024097', '0.19771569604754066', '0.24804066313833364\n']
# ['5', '0.39563155985908216', '0.7622446897868237', '0.1395180558845598', '0.2604568569854873\n']
# /etc/noteable/project/yolov5/custom_dataset/labels/val/image_0016.txt
# ['0', '0.8931451612903223', '0.7974910394265232', '0.2137096774193545', '0.26164874551971357\n']
# /etc/noteable/project/yolov5/custom_dataset/labels/val/image_0012.txt
# ...

# %%
# !ls yolov5/custom_dataset/images/train/
# Out:
# image_0000.png	image_1133.png	image_2266.png	image_3399.png	image_4532.png
# image_0001.png	image_1134.png	image_2267.png	image_3400.png	image_4533.png
# image_0002.png	image_1135.png	image_2268.png	image_3401.png	image_4534.png
# image_0003.png	image_1136.png	image_2269.png	image_3402.png	image_4535.png
# image_0004.png	image_1137.png	image_2270.png	image_3403.png	image_4536.png
# image_0005.png	image_1138.png	image_2271.png	image_3404.png	image_4537.png
# image_0006.png	image_1139.png	image_2272.png	image_3405.png	image_4538.png
# image_0007.png	image_1140.png	image_2273.png	image_3406.png	image_4539.png
# image_0008.png	image_1141.png	image_2274.png	image_3407.png	image_4540.png
# image_0009.png	image_1142.png	image_2275.png	image_3408.png	image_4541.png
# image_0010.png	image_1143.png	image_2276.png	image_3409.png	image_4542.png
# image_0011.png	image_1144.png	image_2277.png	image_3410.png	image_4543.png
# ...

# %%
# !ls yolov5/custom_dataset/images/val/
# Out:
# image_0000.png	image_0160.png	image_0320.png	image_0480.png	image_0640.png
# image_0001.png	image_0161.png	image_0321.png	image_0481.png	image_0641.png
# image_0002.png	image_0162.png	image_0322.png	image_0482.png	image_0642.png
# image_0003.png	image_0163.png	image_0323.png	image_0483.png	image_0643.png
# image_0004.png	image_0164.png	image_0324.png	image_0484.png	image_0644.png
# image_0005.png	image_0165.png	image_0325.png	image_0485.png	image_0645.png
# image_0006.png	image_0166.png	image_0326.png	image_0486.png	image_0646.png
# image_0007.png	image_0167.png	image_0327.png	image_0487.png	image_0647.png
# image_0008.png	image_0168.png	image_0328.png	image_0488.png	image_0648.png
# image_0009.png	image_0169.png	image_0329.png	image_0489.png	image_0649.png
# image_0010.png	image_0170.png	image_0330.png	image_0490.png	image_0650.png
# image_0011.png	image_0171.png	image_0331.png	image_0491.png	image_0651.png
# ...

# %%
# !cat yolov5/custom_dataset/labels/val/image_0787.txt
# Out:
# 0 0.5579710144927537 0.8043478260869571 0.2101449275362319 0.20772946859903418
# 0 0.28079710144927544 0.7850241545893717 0.20108695652173922 0.27214170692431533
# 0 0.794836956521739 0.817230273752013 0.11503623188405797 0.10466988727858294

# %%
# !cat yolov5/custom_dataset/labels/val/image_0785.txt
# Out:
# 0 0.8795289855072467 0.788244766505636 0.15942028985507237 0.2721417069243152

# %%
# !python3 yolov5/custom_dataset/generate_path.py
# Out:
# ['My First Notebook.ipynb', 'classes.names', 'custom.yaml', 'generate_path.py', 'object_detection.ipynb', 'object_detection_mel.ipynb', 'reannotate.py', 'yolov5s.pt', '.git', '.gitignore', '.tmp', 'yolov5']

# %%
# !ls yolov5/custom_dataset/
# Out:
# classes.names  generate_path.py  images  labels  reannotate.py

# %%
# !ls
# Out:
#  classes.names	   'My First Notebook.ipynb'	 reannotate.py	 yolov5
#  custom.yaml	    object_detection.ipynb	 train.txt	 yolov5s.pt
#  generate_path.py   object_detection_mel.ipynb	 val.txt

# %%
# !cat train.txt
# Out:
# /etc/noteable/project/yolov5/custom_dataset/images/train/.noteablekeep
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4655.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4676.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4654.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4667.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4660.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4680.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4673.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4674.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4670.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4661.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4671.png
# /etc/noteable/project/yolov5/custom_dataset/images/train/image_4664.png
# ...

# %%
# !head -n -1 train.txt >: train.txt

# %%
# !cp train.txt yolov5/custom_dataset
# !cp val.txt yolov5/custom_dataset

# %%
# !cp yolov5s.pt yolov5/

# %%
# !python yolov5/train.py --img 640 --epochs 1 --data custom.yaml --weights yolov5s.pt --batch-size 4 --workers 4
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=1, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=4, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.9.13 torch-2.0.1+cu117 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !ls yolov5/runs/train/exp2/weights
# Out:
# best.pt  last.pt

# %%
# !cp yolov5/runs/train/exp2/weights/best.pt /etc/noteable/project/

# %%
ls /etc/noteable/project/
# Out:
#  :               generate_path.py             reannotate.py   yolov5s.pt
#  best.pt        'My First Notebook.ipynb'     train.txt
#  classes.names   object_detection.ipynb       val.txt
#  custom.yaml     object_detection_mel.ipynb   yolov5/
